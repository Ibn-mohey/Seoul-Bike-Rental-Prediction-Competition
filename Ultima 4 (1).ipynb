# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_log_error
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,GradientBoostingRegressor
from sklearn.inspection import permutation_importance
from sklearn.utils import shuffle
import xgboost as xgb
import catboost as cb

# %%
#---------- configs
pd.set_option('max_rows',100)
pd.set_option('max_columns',40)

# %% [markdown]
# ### loading data

# %%
train_path = r"train.csv"
test_path = r"test.csv"

# %%
df = pd.read_csv(train_path,index_col=0,parse_dates=['Date'],dayfirst=True)
df_test = pd.read_csv(test_path,parse_dates=['Date'],dayfirst=True)

df = df.rename(columns={'Temperature(�C)':'Temperature(C)','Dew point temperature(�C)'  : 'Dew point temperature(C)'})
df_test = df_test.rename(columns={'Temperature(�C)':'Temperature(C)','Dew point temperature(�C)'  : 'Dew point temperature(C)'})

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ##### based on the previous notebook (eda) we will consider the following
#
# - A) The Hourly cycle has a good correlation. [7am-18pm has the bigger share]
# - B) The Temperature has good corr. [high is good except > ~ 27]
# - C) The Functional Day has good corr. [functional is good for target]
# - D) The Seasons has good corr. [hot season is better]
#
# -------------
#
# - E) The Visibility may prove to be good. [if encoded to very_low visibility vs normal visibiliy].
# - F) The RainFall/SnowFall may prove to be good. [if encoded to Snowing / Raining or not].
# - G) The Humidity may have something to investigate. [if encoded as 0-80 % normal rentals, 80-100% show sharp decay in rentals]
#
# ---------------
# - H) the Dew point temperature is strongly corr to Temperature will drop it.
# - I) the Solar Radiation may be discarded .. i didn't see good relation.
# - J) the holidays didn't prove decisive saying on our target. maybe discarded too.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5760 entries, 0 to 5759
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      5760 non-null   datetime64[ns]
#  1   y                         5760 non-null   int64
#  2   Hour                      5760 non-null   int64
#  3   Temperature(C)            5760 non-null   float64
#  4   Humidity(%)               5760 non-null   int64
#  5   Wind speed (m/s)          5760 non-null   float64
#  6   Visibility (10m)          5760 non-null   int64
#  7   Dew point temperature(C)  5760 non-null   float64
#  8   Solar Radiation (MJ/m2)   5760 non-null   float64
#  9   Rainfall(mm)              5760 non-null   float64
#  10  Snowfall (cm)             5760 non-null   float64
#  11  Seasons                   5760 non-null   object
#  12  Holiday                   5760 non-null   object
#  13  Functioning Day           5760 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 675.0+ KB

# %%
df.describe()
# Out:
#                  y         Hour  Temperature(C)  Humidity(%)  \
# count  5760.000000  5760.000000     5760.000000  5760.000000
# mean    703.483854    11.500000       12.803559    58.361806
# std     655.249491     6.922788       11.902206    19.840167
# min       0.000000     0.000000      -15.100000     0.000000
# 25%     188.000000     5.750000        3.200000    43.000000
# 50%     485.500000    11.500000       13.700000    57.000000
# 75%    1066.000000    17.250000       22.225000    73.000000
# max    3556.000000    23.000000       39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# count       5760.000000       5760.000000               5760.000000
# mean           1.723333       1473.711458                  4.058264
# std            1.047898        585.879880                 13.003582
# min            0.000000         27.000000                -26.900000
# 25%            0.900000       1025.750000                 -5.400000
# 50%            1.500000       1732.000000                  5.200000
# 75%            2.300000       2000.000000                 14.700000
# max            7.400000       2000.000000                 27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              5760.000000   5760.000000    5760.000000
# mean                  0.572325      0.135122       0.046302
# std                   0.869943      1.075320       0.323728
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.940000      0.000000       0.000000
# max                   3.520000     35.000000       5.100000

# %%
len(df[(df['Snowfall (cm)'])>=1.5])
# Out:
# 84

# %%
df['Seasons'].value_counts()
# Out:
# Winter    1440
# Spring    1440
# Summer    1440
# Autumn    1440
# Name: Seasons, dtype: int64

# %%
df_prep = df.copy()

# %%
df_prep['Year'] = df['Date'].dt.year.astype('int')
df_prep['Week'] = df['Date'].dt.isocalendar().week.astype('int')
df_prep['Month'] = df['Date'].dt.month.astype('int')
df_prep['WeekDay'] = df['Date'].dt.weekday.astype('int')

# %%
def restore_data_series(dataframe,dforiginal,col_name):
    dataframe[col_name] = dforiginal[col_name]

# %%
def map_data_series(dataframe,col_name,from_vals,to_vals):
    dataframe[col_name].replace(from_vals,to_vals,inplace=True)

# %%
def new_feature_data_series(dataframe,col_name,function,new_col_name):
       dataframe[new_col_name]  = dataframe[col_name].apply(function,axis=1)

# %%
map_data_series(df_prep,'Functioning Day',['Yes','No'],[1,0])

# %%
map_data_series(df_prep,'Holiday',['Holiday','No Holiday'],[1,0])

# %%
map_data_series(df_prep,'Seasons',['Winter','Spring','Summer','Autumn'],[0,1,2,3])

# %% [raw]
# # feature eng for hour of the day
# around 8 am & around 6 pm (18) there is a peak in rentals
# around 4 am we hit the daily.
# how can we factor that?

# %%
## lambda df : 0 if ( (abs(df['Hour'] - 8) <=rush_range_1) or (abs(df['Hour'] - 18) <= rush_range_2) ) else 1
def rush_hour(df):
    #rush_range_1 = 2 # around the rush hour by +- 2 hrs
    #rush_range_2 = 4 # around the rush hour by +- 4 hrs
    if (df['Hour'] in [6,7,8,9,10,16,17,18,19,20]):
        return 1
    else:
        return 0
    
def rush_hour_grad_2(df):
    rush_range_1 = 2 # around the rush hour by +- 2 hrs
    rush_range_2 = 5 # around the rush hour by +- 4 hrs
    is_functional = df['Functioning Day']

    return (np.exp(-abs(df['Hour'] - 8)) +  np.exp(-abs(df['Hour'] - 18))) * is_functional

def rush_hour_grad(df):
    #from 8 am , 6 pm
    rush_range_1 = 2 # around the rush hour by +- 2 hrs
    rush_range_2 = 5 # around the rush hour by +- 4 hrs
    is_functional = df['Functioning Day'] 
    
    if (abs(df['Hour'] - 8) <= rush_range_1): 
        return np.exp(-abs(df['Hour'] - 8)) * is_functional
    
    elif (abs(df['Hour'] - 18) <= rush_range_2):
        return np.exp(-abs(df['Hour'] - 18)) * is_functional
    else:
        return 0
    
def dead_hour_grad(df):
    dead_range_1 = 3 # around the dead hour by +- 3 hrs from 4 am
    is_functional = df['Functioning Day'] 
    
    if (abs(df['Hour'] - 4) <= dead_range_1): 
        return np.exp(-abs(df['Hour'] - 4)) * is_functional
    else:
        return 0
    
def dead_hour_grad_2(df):
    #dead_range_1 = 5 # around the dead hour by +- 3 hrs from 4 am
    is_functional = df['Functioning Day'] 
    
    if(df['Hour'] in [22,23,0,1,2,3,4,5]):
        return np.exp(-abs(df['Hour'] - 4)) * is_functional
    else:
        return 0   
new_feature_data_series(df_prep,['Hour','Functioning Day'],rush_hour_grad,'Rush_hour')
new_feature_data_series(df_prep,['Hour','Functioning Day'],dead_hour_grad_2,'Dead_hour')

# %%
## lambda df : 0 if ( (abs(df['Hour'] - 8) <=rush_range_1) or (abs(df['Hour'] - 18) <= rush_range_2) ) else 1
def day_night(df):
    #rush_range_1 = 2 # around the rush hour by +- 2 hrs
    #rush_range_2 = 4 # around the rush hour by +- 4 hrs
    if (df['Hour'] >=6 and df['Hour'] <=18):
        return 1
    else:
        return 0

new_feature_data_series(df_prep,['Hour'],day_night,'day_night')

# %% [raw]
# # for humidity
# increase from 0 to 50% , decay from 50 to 100%
# how can we factor that?

# %%
new_feature_data_series(df_prep,['Humidity(%)'],lambda df : 0 if (df['Humidity(%)'] <= 70) else 1,'Humidity_high')

# %%
new_feature_data_series(df_prep,['Temperature(C)'],lambda df : 0 if (df['Temperature(C)'] <= 35) else 1,'Temperature_high')

# %%
new_feature_data_series(df_prep,['Humidity(%)','Temperature(C)','Solar Radiation (MJ/m2)','Wind speed (m/s)'],lambda df : 0 if (df['Temperature(C)'] < 35) and (df['Humidity(%)'] < 70) and (df['Solar Radiation (MJ/m2)'] < 1.4) else 1,'Weather_bad')

# %%
def humidex(df):
    ### humidex
    ## eq H = Tair + 5/9 * [(6.11 * e^5417.7530 * (a-b)) - 10 ]
    Tair = df['Temperature(C)']
    Tdew = df['Dew point temperature(C)']
    is_functionalDay = df['Functioning Day']
    a = 1/273.16
    b = 1/(273.15 + Tdew)
    Humidex = Tair + (5/9) * (6.11 * np.exp(5417.7530 * (a-b)) -10)
    return Humidex  
new_feature_data_series(df_prep,['Temperature(C)','Dew point temperature(C)','Functioning Day'],humidex,'Humidex')

# %%
df_prep['Ideal'] = df[['Temperature(C)', 'Wind speed (m/s)']] \
    .apply(lambda df: 1 if (df['Temperature(C)'] < 30 and df['Wind speed (m/s)'] < 2.8) else 0, axis = 1)

# %%
df_prep["Ideal"].value_counts()
# Out:
# 1    4548
# 0    1212
# Name: Ideal, dtype: int64

# %% [raw]
# # for visibility
# three important ranges very low , low low , normal_>
# how can we factor that?

# %%
def visibility(df):
    #0:250 , 250:500 : 500:inf
    
    if df['Visibility (10m)'] <=250 :
        return 0
    elif df['Visibility (10m)'] <=350 :
        return 1
    elif df['Visibility (10m)'] <=450 :
        return 1
    elif df['Visibility (10m)'] <=550 :
        return 2
    elif df['Visibility (10m)'] <=650 :
        return 2
    elif df['Visibility (10m)'] <=850 :
        return 3
    elif df['Visibility (10m)'] <=1150 :
        return 3
    elif df['Visibility (10m)'] <=1350 :
        return 4
    else:
        return 5
    
new_feature_data_series(df_prep,['Visibility (10m)'],visibility,'Visibility_cat')

# %%
def visibility_dist(df):
    #0:250 , 250:500 : 500:inf
    
    if df['Visibility (10m)'] <100 :     #can't see
        return 1
    elif df['Visibility (10m)'] <400 :   # foggy
        return 2
    elif df['Visibility (10m)'] <1000 :  # low fog
        return 3
    elif df['Visibility (10m)'] <2000 :  # no fog (good vision)
        return 4
    elif df['Visibility (10m)'] <4000 :  # no fog (excellent vision)
        return 5
    else:
        return 5
    
new_feature_data_series(df_prep,['Visibility (10m)'],visibility_dist,'Visibility_dist')

# %%
# for rainfall

def rain_fall(df):
    # 0:2.5 , 
    
    if df['Rainfall(mm)'] < 0.5 :
        return 0
    else:
        return 1

new_feature_data_series(df_prep,['Rainfall(mm)'],rain_fall,'Rain_cat')

# %%
def snow_fall(df):
    # 0:2.5 , 
    
    if df['Snowfall (cm)'] == 0 :
        return 0
    else:
        return 1

new_feature_data_series(df_prep,['Snowfall (cm)'],snow_fall,'Snow_cat')

# %%
def Sunny_Hot (df):
    if ((df['Temperature(C)']>25)&((df['Solar Radiation (MJ/m2)'] >2)&(df['day_night']==1))):
        return True
    else:
        return False

def Clear_hot (df):
    if ((df['Temperature(C)']>25)&(((df['Solar Radiation (MJ/m2)'] <=2)&(df['Solar Radiation (MJ/m2)'] >1))\
                                   &(df['day_night']==1))&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def PCloudy_hot(df):  
    if((df['Temperature(C)']>25)&(((df['Solar Radiation (MJ/m2)'] <=1)&(df['Solar Radiation (MJ/m2)'] >0.5))\
                                                       &(df['day_night']==1))&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Cloudy_hot(df): 
    if((df['Temperature(C)']>25)&(((df['Solar Radiation (MJ/m2)'] <=0.5))&(df['day_night']==1))\
                      &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Rain_hot(df):  
    if((df['Temperature(C)']>25)&(df['Rainfall(mm)'] >0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def Night_hot(df): 
    if((df['Temperature(C)']>25)&(df['day_night']==0)
                      &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

#len(sunny_hot)+len(Clear_hot)+len(PCloudy_hot)+len(Cloudy_hot)+len(Rain_hot)+len(Night_hot)

# %%
def Sunny_Warm (df):
    if (((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))&((df['Solar Radiation (MJ/m2)'] >2)&(df['day_night']==1))):
        return True
    else:
        return False

def Clear_Warm (df):
    if (((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))\
        &(((df['Solar Radiation (MJ/m2)'] <=2)&(df['Solar Radiation (MJ/m2)'] >1))&(df['day_night']==1))\
        &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def PCloudy_Warm(df):  
    if(((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))\
       &(((df['Solar Radiation (MJ/m2)'] <=1)&(df['Solar Radiation (MJ/m2)'] >0.5))&(df['day_night']==1))\
       &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Cloudy_Warm(df): 
    if(((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))\
       &(((df['Solar Radiation (MJ/m2)'] <=0.5))&(df['day_night']==1))\
       &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Rain_Warm(df):  
    if(((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))&(df['Rainfall(mm)'] >0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def Night_Warm(df): 
    if(((df['Temperature(C)']<=25)&(df['Temperature(C)']>10))\
       &(df['day_night']==0)&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

# %%
def Sunny_Cold (df):
    if (((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))&((df['Solar Radiation (MJ/m2)'] >2)&(df['day_night']==1))):
        return True
    else:
        return False

def Clear_Cold (df):
    if (((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))\
        &(((df['Solar Radiation (MJ/m2)'] <=2)&(df['Solar Radiation (MJ/m2)'] >1))&(df['day_night']==1))\
        &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def PCloudy_Cold(df):  
    if(((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))\
       &(((df['Solar Radiation (MJ/m2)'] <=1)&(df['Solar Radiation (MJ/m2)'] >0.5))&(df['day_night']==1))\
       &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Cloudy_Cold(df): 
    if(((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))\
       &(((df['Solar Radiation (MJ/m2)'] <=0.5))&(df['day_night']==1))\
       &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Rain_Cold(df):  
    if(((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))&(df['Rainfall(mm)'] >0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Snow_Cold(df):  
    if(((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))&(df['Rainfall(mm)'] ==0)&(df['Snowfall (cm)'] >0)):
        return True
    else:
        return False
def Night_Cold(df): 
    if(((df['Temperature(C)']<=10)&(df['Temperature(C)']>0))\
       &(df['day_night']==0)&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

# %%
def Sunny_Freezing (df):
    if ((df['Temperature(C)']<=0)&((df['Solar Radiation (MJ/m2)'] >2)&(df['day_night']==1))):
        return True
    else:
        return False

def Clear_Freezing (df):
    if ((df['Temperature(C)']<=0)&(((df['Solar Radiation (MJ/m2)'] <=2)&(df['Solar Radiation (MJ/m2)'] >1))\
                                   &(df['day_night']==1))&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False

def PCloudy_Freezing(df):  
    if((df['Temperature(C)']<=0)&(((df['Solar Radiation (MJ/m2)'] <=1)&(df['Solar Radiation (MJ/m2)'] >0.5))\
                                                       &(df['day_night']==1))&(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Cloudy_Freezing(df): 
    if((df['Temperature(C)']<=0)&(((df['Solar Radiation (MJ/m2)'] <=0.5))&(df['day_night']==1))\
                      &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Rain_Freezing(df):  
    if((df['Temperature(C)']<=0)&(df['Rainfall(mm)'] >0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Snow_Freezing(df):  
    if((df['Temperature(C)']<=0)&(df['Rainfall(mm)'] ==0)&(df['Snowfall (cm)'] >0)):
        return True
    else:
        return False

def Night_Freezing(df): 
    if((df['Temperature(C)']<=0)&(df['day_night']==0)
                      &(df['Rainfall(mm)'] == 0)&(df['Snowfall (cm)'] == 0)):
        return True
    else:
        return False
def Rain_Snow(df):
    if (df['Rainfall(mm)'] >0)&(df['Snowfall (cm)'] >0):
        return True
    else:
        return False

#len(sunny_hot)+len(Clear_hot)+len(PCloudy_hot)+len(Cloudy_hot)+len(Rain_hot)+len(Night_hot)

# %%
df_prep['Weather_State'] =df_prep[['Temperature(C)', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: "Sunny_hot" if Sunny_Hot(df)\
           else "Clear_hot" if Clear_hot(df)\
           else "PCloudy_hot" if PCloudy_hot(df)\
           else "Cloudy_hot" if Cloudy_hot(df)\
           else "Rain_hot" if Rain_hot(df)\
           else "Night_hot" if Night_hot(df)\
           else "Sunny_Warm" if Sunny_Warm(df)\
           else "Clear_Warm" if Clear_Warm(df)\
           else "PCloudy_Warm" if PCloudy_Warm(df)\
           else "Cloudy_Warm" if Cloudy_Warm(df)\
           else "Rain_Warm" if Rain_Warm(df)\
           else "Night_Warm" if Night_Warm(df)\
           else "Sunny_Cold" if Sunny_Cold(df)\
           else "Clear_Cold" if Clear_Cold(df)\
           else "PCloudy_Cold" if PCloudy_Cold(df)\
           else "Cloudy_Cold" if Cloudy_Cold(df)\
           else "Rain_Cold" if Rain_Cold(df)\
           else "Snow_Cold" if Snow_Cold(df)\
           else "Night_Cold" if Night_Cold(df)\
           else "Sunny_Freezing" if Sunny_Freezing(df)\
           else "Clear_Freezing" if Clear_Freezing(df)\
           else "PCloudy_Freezing" if PCloudy_Freezing(df)\
           else "Cloudy_Freezing" if Cloudy_Freezing(df)\
           else "Rain_Freezing" if Rain_Freezing(df)\
           else "Snow_Freezing" if Snow_Freezing(df)\
           else "Night_Freezing" if Night_Freezing(df)\
           else "Rain&Snow" if Rain_Snow(df)\
           else 0, axis = 1)

# %%
Weather_Description_list = ['Night_Freezing', 'Cloudy_Freezing', 'PCloudy_Freezing',
                            'Clear_Cold', 'PCloudy_Cold', 'Cloudy_Cold', 'Night_Cold',
                            'Rain_Cold', 'Clear_Freezing', 'Rain&Snow', 'Snow_Freezing',
                            'Snow_Cold', 'Sunny_Freezing', 'Sunny_Cold', 'Sunny_Warm',
                            'Clear_Warm', 'PCloudy_Warm', 'Cloudy_Warm', 'Night_Warm',
                            'Rain_Warm', 'Sunny_hot', 'Clear_hot', 'Cloudy_hot', 'Night_hot',
                            'PCloudy_hot', 'Rain_hot']
length = len(Weather_Description_list)+1
Weather_Description_neumeric = [*range(1, length, 1)]

# %%
map_data_series(df_prep,'Weather_State',Weather_Description_list,Weather_Description_neumeric)

# %%
new_feature_data_series(df_prep,['Weather_State','Visibility_dist'],lambda df :df['Weather_State']*(df['Visibility_dist']),'Weather_stat&visb_dist')

# %%
new_feature_data_series(df_prep,['Weather_State','Visibility (10m)'],lambda df :df['Weather_State']*np.log(df['Visibility (10m)']),'Weather&visb')

# %%
def Clear(df):
    if (df['Solar Radiation (MJ/m2)'] >2) & (df['day_night'] ==1):
        return 1
    else:
        return 0
    
def Few_Clouds(df):
    if (((df['Solar Radiation (MJ/m2)'] <=2)&(df['Solar Radiation (MJ/m2)'] >1.5)) & (df['day_night'] ==1)):
        return 1  
    else:
        return 0
    
def Scatterd_Clouds(df):
    if (((df['Solar Radiation (MJ/m2)'] <=1.5)&(df['Solar Radiation (MJ/m2)'] >1)) & (df['day_night'] ==1)):
        return 1  
    else:
        return 0
    
def Partly_Cloudy(df):
    if (((df['Solar Radiation (MJ/m2)'] <=1)&(df['Solar Radiation (MJ/m2)'] >0.5)) & (df['day_night'] ==1)):
        return 1  
    else:
        return 0
    
def Cloudy(df):
    if ((df['Solar Radiation (MJ/m2)'] <= 0.5) & (df['day_night'] ==1)):
        return 1
    else:
        return 0
    
def Night(df):
    if ((df['Solar Radiation (MJ/m2)'] <= 0.8) & (df['day_night'] ==0)):
        return 1
    else:
        return 0

# %%
def Mist(df):
    if df['Visibility_dist'] == 3:
        return 1
    else:
        return 0
    
def Fog(df):
    if ((df['Visibility_dist'] == 1) | (df['Visibility_dist'] == 2)) :
        return 1
    else:
        return 0

# %%
def Light_Rain(df):
    if ((df['Rainfall(mm)']) >0 & (df['Rainfall(mm)'] < 2.5))  :
        return 1
    else:
        return 0
    
def Heavy_Rain(df):
    if (df['Rainfall(mm)'] >= 2.5)  :
        return 1
    else:
        return 0
def Ice_pallets(df):
        if ((df['Rainfall(mm)'] > 0 )& (df['Snowfall (cm)'] > 0 ))  :
            return 1
        else:
            return 0

# %%
def Light_Snow(df):
    if ((df['Snowfall (cm)']) >0 & (df['Snowfall (cm)'] < 1))  :
        return 1
    else:
        return 0
    
def Snow(df):
    if (df['Snowfall (cm)'] >= 1)  :
        return 1
    else:
        return 0

# %%
def Cond1(df):
    if Clear(df) or Few_Clouds(df) or Partly_Cloudy(df) or Cloudy(df):
        return 1
    else:
        return 0
def Cond2(df):
    if (Mist(df) and Cloudy(df)) or (Mist(df) and Partly_Cloudy(df)) or (Mist(df) and Few_Clouds(df)) or Mist(df):
        return 1
    else:
        return 0
def Cond3(df):
    if Light_Snow(df) or (Light_Rain(df) and Scatterd_Clouds(df)) or Light_Rain(df):
        return 1
    else:
        return 0
def Cond4(df):
    if (Ice_pallets(df) and Mist(df)) or (Snow(df) and Fog(df)) or Snow(df) :
        return 1
    else:
        return 0
def Cond5(df):
    if Night(df):
        return 1
    else:
        return 0

# %%
df_prep['Sky_State'] =df_prep[['Temperature(C)','Visibility_dist', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: 4 if Cond4(df)\
                 else 2 if Cond2(df)\
                 else 3 if Cond3(df)\
                 else 1 if Cond1(df)\
                 
                 else 5, axis = 1)

# %%
def Hot(df):
    if (df['Temperature(C)']>25):
        return 1
    else:
        return 0
def Warm(df):
    if ((df['Temperature(C)']<=25)&(df['Temperature(C)']>10)):
        return 1
    else:
        return 0
def Cold(df):
    if ((df['Temperature(C)']<=10)&(df['Temperature(C)']>0)):
        return 1
    else:
        return 0
def Freezing(df):
    if (df['Temperature(C)']<=0):
        return 1
    else:
        return 0

# %%
df_prep['Temp_State'] =df_prep[['Temperature(C)','Visibility_dist', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: 1 if Warm(df)\
                 else 2 if Cold(df)\
                 else 3 if Hot(df)\
                 else 4 if Freezing(df)\
                 
                 else 5, axis = 1)

# %%
df_prep[["Temp_State"]].value_counts()
# Out:
# Temp_State
# 1             2396
# 2             1358
# 3             1004
# 4             1002
# dtype: int64

# %%
new_feature_data_series(df_prep,['Sky_State','Temp_State'],lambda df :df['Sky_State']*(df['Temp_State']),'GBL_Forecast')

# %%
df_prep["Date_tmp"] = df_prep['Date'].dt.to_period('M')
new_feature_df = pd.DataFrame(df_prep.groupby(['Date_tmp', 'Year'])['y'].mean()).sort_values(["Year"])
new_feature_df = pd.DataFrame(new_feature_df['y'].shift(+1))
new_feature_df.reset_index(inplace=True)
new_feature_df.rename(columns={'y':'Prev Month y'}, inplace=True)
new_feature_df.drop(['Year'], axis = 1, inplace =True)
#new_feature_df.fillna(225, inplace = True)

# %%
df_prep = pd.merge(df_prep, new_feature_df, on='Date_tmp', how='left')

# %%
df_prep['Prev Month y'].fillna((df_prep['Prev Month y'].mean()), inplace=True)

# %%
features=list(df_prep.columns)

# %%
print(features)
print(type(features))
# Out:
# ['Date', 'y', 'Hour', 'Temperature(C)', 'Humidity(%)', 'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons', 'Holiday', 'Functioning Day', 'Year', 'Week', 'Month', 'WeekDay', 'Rush_hour', 'Dead_hour', 'day_night', 'Humidity_high', 'Temperature_high', 'Weather_bad', 'Humidex', 'Ideal', 'Visibility_cat', 'Visibility_dist', 'Rain_cat', 'Snow_cat', 'Weather_State', 'Weather_stat&visb_dist', 'Weather&visb', 'Sky_State', 'Temp_State', 'GBL_Forecast', 'Date_tmp', 'Prev Month y']
# <class 'list'>

# %%
processed_features = features.copy()
print(processed_features)
# Out:
# ['Date', 'y', 'Hour', 'Temperature(C)', 'Humidity(%)', 'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons', 'Holiday', 'Functioning Day', 'Year', 'Week', 'Month', 'WeekDay', 'Rush_hour', 'Dead_hour', 'day_night', 'Humidity_high', 'Temperature_high', 'Weather_bad', 'Humidex', 'Ideal', 'Visibility_cat', 'Visibility_dist', 'Rain_cat', 'Snow_cat', 'Weather_State', 'Weather_stat&visb_dist', 'Weather&visb', 'Sky_State', 'Temp_State', 'GBL_Forecast', 'Date_tmp', 'Prev Month y']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ----
# # Training The Model

# %% [markdown]
# ####  Our Scoring Metric (RMSLE)

# %%
def rmsle(y_true, y_pred, convertExp=True):
    if convertExp:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
        
    log_true = np.nan_to_num(np.array([np.log(y+1.0) for y in y_true]))
    log_pred = np.nan_to_num(np.array([np.log(y+1.0) for y in y_pred]))
    
    output = np.sqrt(np.mean((log_true - log_pred)**2))
    return output

def NumPyRMSLE(y_true:list, y_pred:list) -> float:
    """
        The Root Mean Squared Log Error (RMSLE) metric using only NumPy
        N.B. This function is a lot slower than sklearn's implementation
        
        :param y_true: The ground truth labels given in the dataset
        :param y_pred: Our predictions
        :return: The RMSLE score
    """
    n = len(y_true)
    msle = np.mean([(np.log(y_pred[i] + 1) - np.log(y_true[i] + 1)) ** 2.0 for i in range(n)])
    return np.sqrt(msle)

rmsle_scorer = metrics.make_scorer(rmsle, greater_is_better=False)

# %% [markdown]
# ##### Selecting features and splitting (do this everytime you change the features! and want to do training)

# %%
selected_features = ['Hour','Week', 'Month','Year', 'Solar Radiation (MJ/m2)','Rainfall(mm)',
                     'Snowfall (cm)','Wind speed (m/s)','Visibility (10m)','WeekDay',
                     'Seasons','Holiday' ,'Temperature(C)', 'Humidity(%)',
                    'Functioning Day','Rush_hour','Dead_hour','Weather_State',
                   'Weather&visb','Weather_stat&visb_dist','Sky_State','Temp_State','GBL_Forecast']

#selected_features = ['Hour', 'Temperature(C)', 'Humidity(%)', 'Wind speed (m/s)',
#                     'Dew point temperature(C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons', 'Holiday', 
#                     'Functioning Day', 'Week', 'Month', 'WeekDay', 'Rush_hour', 'Dead_hour', 'day_night'
#                     , 'Humidity_high', 
#                     'Temperature_high'
#                     , 'Humidex', 'Ideal', 'Visibility_cat'
#                     , 'Visibility_dist', 'Rain_cat', 'Snow_cat'
#                     , 'Weather_stat&visb_dist', 'Weather&visb'
#                     , 'Sky_State', 'Temp_State'
#                     , 'GBL_Forecast']


                     
#['Prev Month y'] 'Year',, 'Visibility (10m)', , 'Weather_bad', 'Weather_State'

train = df_prep.copy()
train["y"] = np.log(df_prep["y"]+0.00001) ##--- someone explain why this works better than +1

#train["y"] = df_prep["y"]
X1 = train[selected_features]
y1 = train["y"]
polynomial_X1=X1[selected_features]
trans = PolynomialFeatures(degree=2)
polynomial_X1= trans.fit_transform(polynomial_X1)




# tss = TimeSeriesSplit(n_splits=2)
# train_ind,test_ind  = tss.split(X1,groups=[20,1])

X_train, X_test, y_train, y_test = train_test_split(polynomial_X1, y1, test_size = 0.2, random_state=42,shuffle=True,)

# %%
def rmsle(y_true, y_pred, convertExp=True):
    if convertExp:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
        
    log_true = np.nan_to_num(np.array([np.log(y+1) for y in y_true]))
    log_pred = np.nan_to_num(np.array([np.log(y+1) for y in y_pred]))
    
    output = np.sqrt(np.mean((log_true - log_pred)**2))
    return output

# %% [markdown]
# #Set the minimum error arbitrarily large
# min = 99999999999999999999999
# count = 0 #Used for keeping track of the iteration number
# #How many runs to perform using randomly selected hyperparameters
# iterations = 50
# for i in range(iterations):
#     print('iteration number', count)
#     count += 1 #increment count
#     try:
#         d_train = lgb.Dataset(x_train, label=y_train) #Load in data
#         params = {} #initialize parameters
#         params['learning_rate'] = np.random.uniform(0, 1)
#         params['boosting_type'] = np.random.choice(['gbdt', 'dart', 'goss'])
#         params['objective'] = 'regression'
#         params['metric'] = 'mae'
#         params['sub_feature'] = np.random.uniform(0, 1)
#         params['num_leaves'] = np.random.randint(20, 300)
#         params['min_data'] = np.random.randint(10, 100)
#         params['max_depth'] = np.random.randint(5, 200)
#         iterations = np.random.randint(10, 10000)
#         print(params, iterations)
# #Train using selected parameters
# clf = lgb.train(params, X_train,y_trai, iterations)
# y_pred=clf.predict(X_test) #Create predictions on test set

# %% [markdown]
# #{'lambda_l1': 0, 'lambda_l2': 0, 'min_data_in_leaf': 30, 'num_leaves': 31, 'reg_alpha': 0.1} 0.9911512065626906
# # evaluate lightgbm ensemble for regression
# from numpy import mean
# from numpy import std
# from sklearn.datasets import make_regression
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedKFold
# from lightgbm import LGBMRegressor
# model = LGBMRegressor()
# # evaluate the model
# cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# n_scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# model.fit(X_train, y_train)
# # report performance
# print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# from scipy.stats import randint
# from scipy.stats import uniform
# import numpy as np
# import pandas as pd
# import lightgbm as lgb
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import KFold
# gkf = KFold(n_splits=5, shuffle=True, random_state=42).split(X=X_train, y=y_train)
#
# #param_grid = {
# #    'n_estimators': [400, 700, 1000],
# #    'colsample_bytree': [0.7, 0.8],
# #    'max_depth': [15,20,25],
# #    'reg_alpha': [1.1, 1.2, 1.3],
# #    'reg_lambda': [1.1, 1.2, 1.3],
# #    'subsample': [0.7, 0.8, 0.9]
# #}
# param_grid = {
#     "max_bin":[1200],
#     'learning_rate': [0.03],
#     'n_jobs': [10],
#     "num_leaves":[8],
#     'n_estimators': [3500],
#     'colsample_bytree': [0.9],
#     'max_depth': [3],
#     'reg_alpha': [1.2],
#     'reg_lambda': [1.2],
#     'subsample': [0.9]
# }
#
# lgb_estimator = lgb.LGBMRegressor()
#
# gsearch = GridSearchCV(estimator=lgb_estimator, param_grid=param_grid, cv=gkf)
# lgb_model = gsearch.fit(X=X_train, y=y_train)
#
# print(lgb_model.best_params_, lgb_model.best_score_)

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_log_error
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,GradientBoostingRegressor
from sklearn.inspection import permutation_importance
from sklearn.utils import shuffle
import xgboost as xgb
import catboost as cb

# %%
# make a prediction with a stacking ensemble
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor

# define the base models
level0 = list()




level0.append(('cat', cb.CatBoostRegressor(loss_function='RMSE',random_state=0,max_depth=3,iterations=1900,l2_leaf_reg=2,learning_rate=0.069,subsample=0.8)))
#{'max_depth': [3],'iterations': [2020], 'l2_leaf_reg': [2], 'learning_rate': [0.069],'subsample': [0.8]



level0.append(('gbr', GradientBoostingRegressor(random_state =0,loss='ls',
    
    n_estimators=2100,subsample=0.8,min_samples_leaf = 0.001
    ,max_features=0.9,learning_rate=0.04
    ,verbose =0, criterion='friedman_mse')))





level0.append(('xgb', xgb.XGBRegressor(n_estimators=2100,subsample=0.887
                       ,colsample_bytree = 0.9,colsample_bylevel=0.9,
                       learning_rate=0.05,n_jobs=8,max_depth =3)))


#params={
#   'alpha':[0.1,0.01,0.001,0.0001,0.00001],
#    'learning_rate':['constant','optimal','invscaling','adaptive'],
#    'max_iter':[100,300,600,1000,1200,1500,2000],
#    'penalty':['l2','l1','elasticnet']
#}


# define meta learner model
level1 = LinearRegression()
# define the stacking ensemble
model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(X_train, y_train)
# make a prediction for one example
pred_test = model.predict(X_test)
pred_train=model.predict(X_train)
# Out:
# 0:	learn: 3.4419331	total: 157ms	remaining: 4m 57s
# 1:	learn: 3.2256241	total: 168ms	remaining: 2m 39s
# 2:	learn: 3.0244035	total: 180ms	remaining: 1m 53s
# 3:	learn: 2.8397608	total: 192ms	remaining: 1m 30s
# 4:	learn: 2.6668945	total: 204ms	remaining: 1m 17s
# 5:	learn: 2.5054901	total: 215ms	remaining: 1m 8s
# 6:	learn: 2.3578899	total: 227ms	remaining: 1m 1s
# 7:	learn: 2.2215415	total: 239ms	remaining: 56.6s
# 8:	learn: 2.0963963	total: 251ms	remaining: 52.7s
# 9:	learn: 1.9784725	total: 263ms	remaining: 49.6s
# 10:	learn: 1.8685595	total: 274ms	remaining: 47.1s
# 11:	learn: 1.7616649	total: 286ms	remaining: 45s
# 12:	learn: 1.6643179	total: 297ms	remaining: 43.2s
# 13:	learn: 1.5754708	total: 309ms	remaining: 41.6s
# 14:	learn: 1.4922573	total: 321ms	remaining: 40.3s
# 15:	learn: 1.4170239	total: 333ms	remaining: 39.2s
# 16:	learn: 1.3471663	total: 348ms	remaining: 38.6s
# 17:	learn: 1.2804798	total: 363ms	remaining: 37.9s
# 18:	learn: 1.2194460	total: 376ms	remaining: 37.2s
# 19:	learn: 1.1610977	total: 393ms	remaining: 36.9s
# 20:	learn: 1.1095582	total: 407ms	remaining: 36.4s
# 21:	learn: 1.0620921	total: 418ms	remaining: 35.7s
# 22:	learn: 1.0196790	total: 430ms	remaining: 35.1s
# 23:	learn: 0.9817887	total: 443ms	remaining: 34.6s
# 24:	learn: 0.9472410	total: 454ms	remaining: 34.1s
# 25:	learn: 0.9138934	total: 466ms	remaining: 33.6s
# 26:	learn: 0.8835198	total: 477ms	remaining: 33.1s
# 27:	learn: 0.8529346	total: 489ms	remaining: 32.7s
# 28:	learn: 0.8267828	total: 500ms	remaining: 32.3s
# 29:	learn: 0.8012057	total: 512ms	remaining: 31.9s
# 30:	learn: 0.7779616	total: 523ms	remaining: 31.5s
# 31:	learn: 0.7585651	total: 535ms	remaining: 31.2s
# 32:	learn: 0.7393288	total: 549ms	remaining: 31.1s
# 33:	learn: 0.7216333	total: 564ms	remaining: 31s
# 34:	learn: 0.7059225	total: 580ms	remaining: 30.9s
# 35:	learn: 0.6922338	total: 593ms	remaining: 30.7s
# 36:	learn: 0.6796776	total: 609ms	remaining: 30.7s
# 37:	learn: 0.6671775	total: 623ms	remaining: 30.6s
# 38:	learn: 0.6563171	total: 636ms	remaining: 30.3s
# 39:	learn: 0.6451509	total: 647ms	remaining: 30.1s
# 40:	learn: 0.6336671	total: 659ms	remaining: 29.9s
# 41:	learn: 0.6252857	total: 671ms	remaining: 29.7s
# 42:	learn: 0.6176576	total: 683ms	remaining: 29.5s
# 43:	learn: 0.6099274	total: 694ms	remaining: 29.3s
# 44:	learn: 0.6033371	total: 705ms	remaining: 29.1s
# 45:	learn: 0.5963008	total: 717ms	remaining: 28.9s
# 46:	learn: 0.5906163	total: 729ms	remaining: 28.7s
# 47:	learn: 0.5841765	total: 743ms	remaining: 28.6s
# 48:	learn: 0.5782545	total: 774ms	remaining: 29.2s
# 49:	learn: 0.5730797	total: 797ms	remaining: 29.5s
# 50:	learn: 0.5682684	total: 812ms	remaining: 29.5s
# 51:	learn: 0.5638833	total: 827ms	remaining: 29.4s
# 52:	learn: 0.5593376	total: 840ms	remaining: 29.3s
# 53:	learn: 0.5545772	total: 856ms	remaining: 29.3s
# 54:	learn: 0.5491990	total: 872ms	remaining: 29.2s
# 55:	learn: 0.5451578	total: 885ms	remaining: 29.2s
# 56:	learn: 0.5414087	total: 898ms	remaining: 29s
# 57:	learn: 0.5380082	total: 910ms	remaining: 28.9s
# 58:	learn: 0.5345156	total: 922ms	remaining: 28.8s
# 59:	learn: 0.5310322	total: 936ms	remaining: 28.7s
# 60:	learn: 0.5281089	total: 960ms	remaining: 28.9s
# 61:	learn: 0.5255968	total: 981ms	remaining: 29.1s
# 62:	learn: 0.5218872	total: 996ms	remaining: 29s
# 63:	learn: 0.5190949	total: 1.01s	remaining: 29s
# 64:	learn: 0.5143888	total: 1.02s	remaining: 28.9s
# 65:	learn: 0.5125558	total: 1.03s	remaining: 28.7s
# 66:	learn: 0.5102959	total: 1.04s	remaining: 28.6s
# 67:	learn: 0.5076641	total: 1.06s	remaining: 28.5s
# 68:	learn: 0.5051803	total: 1.07s	remaining: 28.4s
# 69:	learn: 0.5031586	total: 1.08s	remaining: 28.2s
# 70:	learn: 0.5013168	total: 1.09s	remaining: 28.1s
# 71:	learn: 0.4990872	total: 1.1s	remaining: 28s
# 72:	learn: 0.4973232	total: 1.11s	remaining: 27.9s
# 73:	learn: 0.4953206	total: 1.13s	remaining: 27.8s
# 74:	learn: 0.4934233	total: 1.14s	remaining: 27.7s
# 75:	learn: 0.4917079	total: 1.15s	remaining: 27.6s
# 76:	learn: 0.4902783	total: 1.17s	remaining: 27.6s
# 77:	learn: 0.4881669	total: 1.18s	remaining: 27.6s
# 78:	learn: 0.4861606	total: 1.2s	remaining: 27.6s
# 79:	learn: 0.4847576	total: 1.21s	remaining: 27.5s
# 80:	learn: 0.4834676	total: 1.22s	remaining: 27.4s
# 81:	learn: 0.4822217	total: 1.23s	remaining: 27.3s
# 82:	learn: 0.4807712	total: 1.24s	remaining: 27.2s
# 83:	learn: 0.4794215	total: 1.25s	remaining: 27.1s
# 84:	learn: 0.4772149	total: 1.26s	remaining: 27s
# 85:	learn: 0.4748957	total: 1.28s	remaining: 26.9s
# 86:	learn: 0.4733442	total: 1.29s	remaining: 26.8s
# 87:	learn: 0.4724044	total: 1.3s	remaining: 26.7s
# 88:	learn: 0.4700512	total: 1.31s	remaining: 26.7s
# 89:	learn: 0.4679405	total: 1.32s	remaining: 26.6s
# 90:	learn: 0.4663690	total: 1.33s	remaining: 26.5s
# 91:	learn: 0.4651724	total: 1.34s	remaining: 26.4s
# 92:	learn: 0.4641669	total: 1.36s	remaining: 26.4s
# 93:	learn: 0.4632265	total: 1.37s	remaining: 26.4s
# 94:	learn: 0.4623686	total: 1.39s	remaining: 26.4s
# 95:	learn: 0.4607667	total: 1.4s	remaining: 26.4s
# 96:	learn: 0.4593051	total: 1.42s	remaining: 26.3s
# 97:	learn: 0.4571558	total: 1.43s	remaining: 26.3s
# 98:	learn: 0.4562869	total: 1.44s	remaining: 26.2s
# 99:	learn: 0.4555676	total: 1.45s	remaining: 26.1s
# 100:	learn: 0.4543829	total: 1.46s	remaining: 26s
# 101:	learn: 0.4537501	total: 1.47s	remaining: 26s
# 102:	learn: 0.4528029	total: 1.48s	remaining: 25.9s
# 103:	learn: 0.4514692	total: 1.49s	remaining: 25.8s
# 104:	learn: 0.4501643	total: 1.51s	remaining: 25.8s
# 105:	learn: 0.4494436	total: 1.52s	remaining: 25.7s
# 106:	learn: 0.4485900	total: 1.53s	remaining: 25.6s
# 107:	learn: 0.4475180	total: 1.54s	remaining: 25.6s
# 108:	learn: 0.4468174	total: 1.56s	remaining: 25.6s
# 109:	learn: 0.4457147	total: 1.57s	remaining: 25.6s
# 110:	learn: 0.4446668	total: 1.59s	remaining: 25.6s
# 111:	learn: 0.4436216	total: 1.6s	remaining: 25.6s
# 112:	learn: 0.4428681	total: 1.62s	remaining: 25.6s
# 113:	learn: 0.4422149	total: 1.63s	remaining: 25.6s
# 114:	learn: 0.4414921	total: 1.65s	remaining: 25.6s
# 115:	learn: 0.4407064	total: 1.66s	remaining: 25.5s
# 116:	learn: 0.4395991	total: 1.67s	remaining: 25.5s
# 117:	learn: 0.4384612	total: 1.68s	remaining: 25.4s
# 118:	learn: 0.4374991	total: 1.7s	remaining: 25.4s
# 119:	learn: 0.4352620	total: 1.71s	remaining: 25.3s
# 120:	learn: 0.4343138	total: 1.72s	remaining: 25.3s
# 121:	learn: 0.4325778	total: 1.73s	remaining: 25.2s
# 122:	learn: 0.4318384	total: 1.74s	remaining: 25.2s
# 123:	learn: 0.4308662	total: 1.76s	remaining: 25.2s
# 124:	learn: 0.4300386	total: 1.77s	remaining: 25.2s
# 125:	learn: 0.4288201	total: 1.79s	remaining: 25.1s
# 126:	learn: 0.4278283	total: 1.8s	remaining: 25.1s
# 127:	learn: 0.4270971	total: 1.81s	remaining: 25s
# 128:	learn: 0.4262020	total: 1.82s	remaining: 25s
# 129:	learn: 0.4255972	total: 1.83s	remaining: 25s
# 130:	learn: 0.4242940	total: 1.84s	remaining: 24.9s
# 131:	learn: 0.4230245	total: 1.86s	remaining: 24.9s
# 132:	learn: 0.4218227	total: 1.87s	remaining: 24.8s
# 133:	learn: 0.4208081	total: 1.88s	remaining: 24.8s
# 134:	learn: 0.4200688	total: 1.89s	remaining: 24.7s
# 135:	learn: 0.4191803	total: 1.9s	remaining: 24.7s
# 136:	learn: 0.4184848	total: 1.91s	remaining: 24.6s
# 137:	learn: 0.4178025	total: 1.92s	remaining: 24.6s
# 138:	learn: 0.4169552	total: 1.94s	remaining: 24.5s
# 139:	learn: 0.4164051	total: 1.95s	remaining: 24.6s
# 140:	learn: 0.4151418	total: 1.97s	remaining: 24.6s
# 141:	learn: 0.4143870	total: 1.98s	remaining: 24.6s
# 142:	learn: 0.4137787	total: 2s	remaining: 24.5s
# 143:	learn: 0.4131518	total: 2.01s	remaining: 24.5s
# 144:	learn: 0.4123248	total: 2.02s	remaining: 24.4s
# 145:	learn: 0.4117445	total: 2.03s	remaining: 24.4s
# 146:	learn: 0.4107786	total: 2.04s	remaining: 24.3s
# 147:	learn: 0.4100809	total: 2.05s	remaining: 24.3s
# 148:	learn: 0.4094859	total: 2.06s	remaining: 24.3s
# 149:	learn: 0.4083749	total: 2.08s	remaining: 24.2s
# 150:	learn: 0.4078665	total: 2.09s	remaining: 24.2s
# 151:	learn: 0.4073407	total: 2.1s	remaining: 24.1s
# 152:	learn: 0.4067889	total: 2.11s	remaining: 24.1s
# 153:	learn: 0.4062646	total: 2.12s	remaining: 24.1s
# 154:	learn: 0.4052946	total: 2.13s	remaining: 24s
# 155:	learn: 0.4046984	total: 2.15s	remaining: 24.1s
# 156:	learn: 0.4042350	total: 2.16s	remaining: 24s
# 157:	learn: 0.4038667	total: 2.17s	remaining: 24s
# 158:	learn: 0.4033744	total: 2.19s	remaining: 23.9s
# 159:	learn: 0.4016087	total: 2.2s	remaining: 23.9s
# 160:	learn: 0.4007552	total: 2.21s	remaining: 23.9s
# 161:	learn: 0.4001448	total: 2.22s	remaining: 23.8s
# 162:	learn: 0.3993387	total: 2.23s	remaining: 23.8s
# 163:	learn: 0.3983679	total: 2.25s	remaining: 23.8s
# 164:	learn: 0.3976015	total: 2.26s	remaining: 23.8s
# 165:	learn: 0.3970129	total: 2.27s	remaining: 23.7s
# 166:	learn: 0.3966669	total: 2.28s	remaining: 23.7s
# 167:	learn: 0.3961732	total: 2.29s	remaining: 23.6s
# 168:	learn: 0.3955224	total: 2.3s	remaining: 23.6s
# 169:	learn: 0.3950323	total: 2.31s	remaining: 23.6s
# 170:	learn: 0.3945797	total: 2.33s	remaining: 23.5s
# 171:	learn: 0.3942261	total: 2.34s	remaining: 23.5s
# 172:	learn: 0.3938909	total: 2.35s	remaining: 23.5s
# 173:	learn: 0.3931169	total: 2.37s	remaining: 23.5s
# 174:	learn: 0.3926449	total: 2.38s	remaining: 23.5s
# 175:	learn: 0.3921240	total: 2.39s	remaining: 23.4s
# 176:	learn: 0.3911860	total: 2.4s	remaining: 23.4s
# 177:	learn: 0.3906228	total: 2.41s	remaining: 23.4s
# 178:	learn: 0.3901030	total: 2.43s	remaining: 23.3s
# 179:	learn: 0.3897802	total: 2.44s	remaining: 23.3s
# 180:	learn: 0.3889317	total: 2.45s	remaining: 23.3s
# 181:	learn: 0.3883352	total: 2.46s	remaining: 23.2s
# 182:	learn: 0.3880172	total: 2.47s	remaining: 23.2s
# 183:	learn: 0.3874938	total: 2.48s	remaining: 23.1s
# 184:	learn: 0.3869552	total: 2.49s	remaining: 23.1s
# 185:	learn: 0.3864901	total: 2.5s	remaining: 23.1s
# 186:	learn: 0.3861087	total: 2.52s	remaining: 23.1s
# 187:	learn: 0.3854016	total: 2.53s	remaining: 23s
# 188:	learn: 0.3848431	total: 2.54s	remaining: 23s
# 189:	learn: 0.3843450	total: 2.56s	remaining: 23s
# 190:	learn: 0.3836680	total: 2.57s	remaining: 23s
# 191:	learn: 0.3832637	total: 2.59s	remaining: 23s
# 192:	learn: 0.3828693	total: 2.6s	remaining: 23s
# 193:	learn: 0.3824974	total: 2.61s	remaining: 23s
# 194:	learn: 0.3820739	total: 2.63s	remaining: 23s
# 195:	learn: 0.3816931	total: 2.64s	remaining: 22.9s
# 196:	learn: 0.3813783	total: 2.65s	remaining: 22.9s
# 197:	learn: 0.3805862	total: 2.66s	remaining: 22.9s
# 198:	learn: 0.3798273	total: 2.67s	remaining: 22.9s
# 199:	learn: 0.3792577	total: 2.69s	remaining: 22.9s
# 200:	learn: 0.3786482	total: 2.7s	remaining: 22.8s
# 201:	learn: 0.3781379	total: 2.72s	remaining: 22.8s
# 202:	learn: 0.3777805	total: 2.73s	remaining: 22.8s
# 203:	learn: 0.3774261	total: 2.74s	remaining: 22.8s
# 204:	learn: 0.3767279	total: 2.76s	remaining: 22.8s
# 205:	learn: 0.3762817	total: 2.77s	remaining: 22.8s
# 206:	learn: 0.3758340	total: 2.79s	remaining: 22.8s
# 207:	learn: 0.3755031	total: 2.8s	remaining: 22.8s
# 208:	learn: 0.3746018	total: 2.81s	remaining: 22.8s
# 209:	learn: 0.3738948	total: 2.83s	remaining: 22.7s
# 210:	learn: 0.3733381	total: 2.84s	remaining: 22.7s
# 211:	learn: 0.3724582	total: 2.85s	remaining: 22.7s
# 212:	learn: 0.3719208	total: 2.87s	remaining: 22.7s
# 213:	learn: 0.3714378	total: 2.88s	remaining: 22.7s
# 214:	learn: 0.3710727	total: 2.89s	remaining: 22.6s
# 215:	learn: 0.3703453	total: 2.9s	remaining: 22.6s
# 216:	learn: 0.3700886	total: 2.91s	remaining: 22.6s
# 217:	learn: 0.3698153	total: 2.92s	remaining: 22.6s
# 218:	learn: 0.3694489	total: 2.94s	remaining: 22.5s
# 219:	learn: 0.3690241	total: 2.95s	remaining: 22.5s
# 220:	learn: 0.3689316	total: 2.96s	remaining: 22.5s
# 221:	learn: 0.3683992	total: 2.98s	remaining: 22.5s
# 222:	learn: 0.3677792	total: 2.99s	remaining: 22.5s
# 223:	learn: 0.3671523	total: 3s	remaining: 22.4s
# 224:	learn: 0.3663675	total: 3.01s	remaining: 22.4s
# 225:	learn: 0.3659216	total: 3.02s	remaining: 22.4s
# 226:	learn: 0.3655585	total: 3.03s	remaining: 22.4s
# 227:	learn: 0.3651764	total: 3.05s	remaining: 22.3s
# 228:	learn: 0.3647176	total: 3.06s	remaining: 22.3s
# 229:	learn: 0.3643294	total: 3.07s	remaining: 22.3s
# 230:	learn: 0.3638594	total: 3.08s	remaining: 22.3s
# 231:	learn: 0.3635337	total: 3.09s	remaining: 22.2s
# 232:	learn: 0.3630366	total: 3.1s	remaining: 22.2s
# 233:	learn: 0.3627104	total: 3.11s	remaining: 22.2s
# 234:	learn: 0.3623027	total: 3.13s	remaining: 22.2s
# 235:	learn: 0.3619499	total: 3.14s	remaining: 22.2s
# 236:	learn: 0.3618861	total: 3.15s	remaining: 22.1s
# 237:	learn: 0.3615525	total: 3.17s	remaining: 22.1s
# 238:	learn: 0.3611705	total: 3.18s	remaining: 22.1s
# 239:	learn: 0.3607248	total: 3.19s	remaining: 22.1s
# 240:	learn: 0.3604393	total: 3.21s	remaining: 22.1s
# 241:	learn: 0.3598949	total: 3.22s	remaining: 22s
# 242:	learn: 0.3596457	total: 3.23s	remaining: 22s
# 243:	learn: 0.3594162	total: 3.24s	remaining: 22s
# 244:	learn: 0.3591795	total: 3.25s	remaining: 22s
# 245:	learn: 0.3588368	total: 3.26s	remaining: 21.9s
# 246:	learn: 0.3585603	total: 3.27s	remaining: 21.9s
# 247:	learn: 0.3584775	total: 3.28s	remaining: 21.9s
# 248:	learn: 0.3582648	total: 3.29s	remaining: 21.8s
# 249:	learn: 0.3579081	total: 3.31s	remaining: 21.8s
# 250:	learn: 0.3574453	total: 3.32s	remaining: 21.8s
# 251:	learn: 0.3573876	total: 3.33s	remaining: 21.8s
# 252:	learn: 0.3571060	total: 3.34s	remaining: 21.7s
# 253:	learn: 0.3567218	total: 3.35s	remaining: 21.7s
# 254:	learn: 0.3564323	total: 3.37s	remaining: 21.7s
# 255:	learn: 0.3562239	total: 3.38s	remaining: 21.7s
# 256:	learn: 0.3559685	total: 3.39s	remaining: 21.7s
# 257:	learn: 0.3557333	total: 3.4s	remaining: 21.7s
# 258:	learn: 0.3551060	total: 3.42s	remaining: 21.6s
# 259:	learn: 0.3548125	total: 3.43s	remaining: 21.6s
# 260:	learn: 0.3546927	total: 3.44s	remaining: 21.6s
# 261:	learn: 0.3539466	total: 3.45s	remaining: 21.6s
# 262:	learn: 0.3535721	total: 3.46s	remaining: 21.6s
# 263:	learn: 0.3532537	total: 3.47s	remaining: 21.5s
# 264:	learn: 0.3532089	total: 3.48s	remaining: 21.5s
# 265:	learn: 0.3527405	total: 3.5s	remaining: 21.5s
# 266:	learn: 0.3524942	total: 3.51s	remaining: 21.4s
# 267:	learn: 0.3522609	total: 3.52s	remaining: 21.4s
# 268:	learn: 0.3518229	total: 3.53s	remaining: 21.4s
# 269:	learn: 0.3515316	total: 3.55s	remaining: 21.4s
# 270:	learn: 0.3512320	total: 3.56s	remaining: 21.4s
# 271:	learn: 0.3511829	total: 3.58s	remaining: 21.4s
# 272:	learn: 0.3509295	total: 3.59s	remaining: 21.4s
# 273:	learn: 0.3506181	total: 3.6s	remaining: 21.4s
# 274:	learn: 0.3501409	total: 3.62s	remaining: 21.4s
# 275:	learn: 0.3497975	total: 3.63s	remaining: 21.3s
# 276:	learn: 0.3491346	total: 3.64s	remaining: 21.3s
# 277:	learn: 0.3481872	total: 3.65s	remaining: 21.3s
# 278:	learn: 0.3480013	total: 3.66s	remaining: 21.3s
# 279:	learn: 0.3477116	total: 3.67s	remaining: 21.3s
# 280:	learn: 0.3473024	total: 3.69s	remaining: 21.2s
# 281:	learn: 0.3470446	total: 3.7s	remaining: 21.2s
# 282:	learn: 0.3466798	total: 3.71s	remaining: 21.2s
# 283:	learn: 0.3459944	total: 3.72s	remaining: 21.2s
# 284:	learn: 0.3456926	total: 3.73s	remaining: 21.1s
# 285:	learn: 0.3456466	total: 3.74s	remaining: 21.1s
# 286:	learn: 0.3453163	total: 3.75s	remaining: 21.1s
# 287:	learn: 0.3449469	total: 3.77s	remaining: 21.1s
# 288:	learn: 0.3447328	total: 3.78s	remaining: 21.1s
# 289:	learn: 0.3443659	total: 3.8s	remaining: 21.1s
# 290:	learn: 0.3440584	total: 3.81s	remaining: 21.1s
# 291:	learn: 0.3438202	total: 3.82s	remaining: 21s
# 292:	learn: 0.3433804	total: 3.83s	remaining: 21s
# 293:	learn: 0.3429409	total: 3.85s	remaining: 21s
# 294:	learn: 0.3425873	total: 3.86s	remaining: 21s
# 295:	learn: 0.3423199	total: 3.87s	remaining: 21s
# 296:	learn: 0.3421311	total: 3.88s	remaining: 20.9s
# 297:	learn: 0.3413503	total: 3.89s	remaining: 20.9s
# 298:	learn: 0.3409416	total: 3.9s	remaining: 20.9s
# 299:	learn: 0.3404620	total: 3.92s	remaining: 20.9s
# 300:	learn: 0.3404179	total: 3.93s	remaining: 20.9s
# 301:	learn: 0.3397848	total: 3.94s	remaining: 20.8s
# 302:	learn: 0.3394584	total: 3.95s	remaining: 20.8s
# 303:	learn: 0.3390241	total: 3.96s	remaining: 20.8s
# 304:	learn: 0.3388418	total: 3.98s	remaining: 20.8s
# 305:	learn: 0.3382973	total: 3.99s	remaining: 20.8s
# 306:	learn: 0.3380773	total: 4s	remaining: 20.8s
# 307:	learn: 0.3380351	total: 4.01s	remaining: 20.7s
# 308:	learn: 0.3378145	total: 4.03s	remaining: 20.7s
# 309:	learn: 0.3374148	total: 4.04s	remaining: 20.7s
# 310:	learn: 0.3372163	total: 4.05s	remaining: 20.7s
# 311:	learn: 0.3369555	total: 4.06s	remaining: 20.7s
# 312:	learn: 0.3366680	total: 4.07s	remaining: 20.6s
# 313:	learn: 0.3364340	total: 4.08s	remaining: 20.6s
# 314:	learn: 0.3362746	total: 4.09s	remaining: 20.6s
# 315:	learn: 0.3359321	total: 4.1s	remaining: 20.6s
# 316:	learn: 0.3357767	total: 4.12s	remaining: 20.6s
# 317:	learn: 0.3355462	total: 4.13s	remaining: 20.5s
# 318:	learn: 0.3351758	total: 4.14s	remaining: 20.5s
# 319:	learn: 0.3348356	total: 4.15s	remaining: 20.5s
# 320:	learn: 0.3343465	total: 4.16s	remaining: 20.5s
# 321:	learn: 0.3342845	total: 4.17s	remaining: 20.5s
# 322:	learn: 0.3340610	total: 4.19s	remaining: 20.5s
# 323:	learn: 0.3336409	total: 4.2s	remaining: 20.4s
# 324:	learn: 0.3331187	total: 4.21s	remaining: 20.4s
# 325:	learn: 0.3328734	total: 4.23s	remaining: 20.4s
# 326:	learn: 0.3326904	total: 4.24s	remaining: 20.4s
# 327:	learn: 0.3323259	total: 4.25s	remaining: 20.4s
# 328:	learn: 0.3322534	total: 4.26s	remaining: 20.3s
# 329:	learn: 0.3319424	total: 4.27s	remaining: 20.3s
# 330:	learn: 0.3315806	total: 4.28s	remaining: 20.3s
# 331:	learn: 0.3313483	total: 4.29s	remaining: 20.3s
# 332:	learn: 0.3304013	total: 4.31s	remaining: 20.3s
# 333:	learn: 0.3302385	total: 4.32s	remaining: 20.2s
# 334:	learn: 0.3299722	total: 4.33s	remaining: 20.2s
# 335:	learn: 0.3297037	total: 4.34s	remaining: 20.2s
# 336:	learn: 0.3289671	total: 4.35s	remaining: 20.2s
# 337:	learn: 0.3283997	total: 4.37s	remaining: 20.2s
# 338:	learn: 0.3280911	total: 4.38s	remaining: 20.2s
# 339:	learn: 0.3277511	total: 4.4s	remaining: 20.2s
# 340:	learn: 0.3274987	total: 4.41s	remaining: 20.2s
# 341:	learn: 0.3272285	total: 4.42s	remaining: 20.1s
# 342:	learn: 0.3270869	total: 4.43s	remaining: 20.1s
# 343:	learn: 0.3267229	total: 4.44s	remaining: 20.1s
# 344:	learn: 0.3265176	total: 4.45s	remaining: 20.1s
# 345:	learn: 0.3261956	total: 4.47s	remaining: 20.1s
# 346:	learn: 0.3258956	total: 4.48s	remaining: 20s
# 347:	learn: 0.3257277	total: 4.49s	remaining: 20s
# 348:	learn: 0.3253622	total: 4.5s	remaining: 20s
# 349:	learn: 0.3251282	total: 4.51s	remaining: 20s
# 350:	learn: 0.3245506	total: 4.53s	remaining: 20s
# 351:	learn: 0.3243782	total: 4.54s	remaining: 20s
# 352:	learn: 0.3240383	total: 4.55s	remaining: 19.9s
# 353:	learn: 0.3237133	total: 4.57s	remaining: 19.9s
# 354:	learn: 0.3234308	total: 4.58s	remaining: 19.9s
# 355:	learn: 0.3228235	total: 4.59s	remaining: 19.9s
# 356:	learn: 0.3223675	total: 4.61s	remaining: 19.9s
# 357:	learn: 0.3221846	total: 4.62s	remaining: 19.9s
# 358:	learn: 0.3218644	total: 4.63s	remaining: 19.9s
# 359:	learn: 0.3215468	total: 4.64s	remaining: 19.9s
# 360:	learn: 0.3213961	total: 4.65s	remaining: 19.8s
# 361:	learn: 0.3211857	total: 4.66s	remaining: 19.8s
# 362:	learn: 0.3208826	total: 4.68s	remaining: 19.8s
# 363:	learn: 0.3204557	total: 4.69s	remaining: 19.8s
# 364:	learn: 0.3203020	total: 4.7s	remaining: 19.8s
# 365:	learn: 0.3200175	total: 4.71s	remaining: 19.7s
# 366:	learn: 0.3194294	total: 4.72s	remaining: 19.7s
# 367:	learn: 0.3192055	total: 4.74s	remaining: 19.7s
# 368:	learn: 0.3189978	total: 4.75s	remaining: 19.7s
# 369:	learn: 0.3187646	total: 4.76s	remaining: 19.7s
# 370:	learn: 0.3186613	total: 4.78s	remaining: 19.7s
# 371:	learn: 0.3184494	total: 4.79s	remaining: 19.7s
# 372:	learn: 0.3180990	total: 4.8s	remaining: 19.7s
# 373:	learn: 0.3178892	total: 4.81s	remaining: 19.6s
# 374:	learn: 0.3173988	total: 4.82s	remaining: 19.6s
# 375:	learn: 0.3170316	total: 4.84s	remaining: 19.6s
# 376:	learn: 0.3167878	total: 4.85s	remaining: 19.6s
# 377:	learn: 0.3163656	total: 4.86s	remaining: 19.6s
# 378:	learn: 0.3160404	total: 4.87s	remaining: 19.5s
# 379:	learn: 0.3157348	total: 4.88s	remaining: 19.5s
# 380:	learn: 0.3155687	total: 4.89s	remaining: 19.5s
# 381:	learn: 0.3154471	total: 4.91s	remaining: 19.5s
# 382:	learn: 0.3149843	total: 4.92s	remaining: 19.5s
# 383:	learn: 0.3148099	total: 4.93s	remaining: 19.5s
# 384:	learn: 0.3146544	total: 4.94s	remaining: 19.4s
# 385:	learn: 0.3144602	total: 4.95s	remaining: 19.4s
# 386:	learn: 0.3140798	total: 4.97s	remaining: 19.4s
# 387:	learn: 0.3139580	total: 4.98s	remaining: 19.4s
# 388:	learn: 0.3137380	total: 4.99s	remaining: 19.4s
# 389:	learn: 0.3134720	total: 5s	remaining: 19.4s
# 390:	learn: 0.3131595	total: 5.01s	remaining: 19.4s
# 391:	learn: 0.3129696	total: 5.03s	remaining: 19.3s
# 392:	learn: 0.3125201	total: 5.04s	remaining: 19.3s
# 393:	learn: 0.3123652	total: 5.05s	remaining: 19.3s
# 394:	learn: 0.3121664	total: 5.06s	remaining: 19.3s
# 395:	learn: 0.3118881	total: 5.07s	remaining: 19.3s
# 396:	learn: 0.3118219	total: 5.08s	remaining: 19.2s
# 397:	learn: 0.3116927	total: 5.09s	remaining: 19.2s
# 398:	learn: 0.3115193	total: 5.1s	remaining: 19.2s
# 399:	learn: 0.3110712	total: 5.12s	remaining: 19.2s
# 400:	learn: 0.3110398	total: 5.13s	remaining: 19.2s
# 401:	learn: 0.3108141	total: 5.14s	remaining: 19.2s
# 402:	learn: 0.3107086	total: 5.15s	remaining: 19.1s
# 403:	learn: 0.3105398	total: 5.16s	remaining: 19.1s
# 404:	learn: 0.3103820	total: 5.18s	remaining: 19.1s
# 405:	learn: 0.3100227	total: 5.19s	remaining: 19.1s
# 406:	learn: 0.3099280	total: 5.2s	remaining: 19.1s
# 407:	learn: 0.3096883	total: 5.21s	remaining: 19.1s
# 408:	learn: 0.3094247	total: 5.23s	remaining: 19.1s
# 409:	learn: 0.3091996	total: 5.24s	remaining: 19s
# 410:	learn: 0.3090264	total: 5.25s	remaining: 19s
# 411:	learn: 0.3088817	total: 5.26s	remaining: 19s
# 412:	learn: 0.3087606	total: 5.27s	remaining: 19s
# 413:	learn: 0.3085904	total: 5.28s	remaining: 19s
# 414:	learn: 0.3082683	total: 5.29s	remaining: 18.9s
# 415:	learn: 0.3080849	total: 5.3s	remaining: 18.9s
# 416:	learn: 0.3075694	total: 5.32s	remaining: 18.9s
# 417:	learn: 0.3074369	total: 5.33s	remaining: 18.9s
# 418:	learn: 0.3072083	total: 5.34s	remaining: 18.9s
# 419:	learn: 0.3069293	total: 5.35s	remaining: 18.9s
# 420:	learn: 0.3066209	total: 5.37s	remaining: 18.8s
# 421:	learn: 0.3064769	total: 5.38s	remaining: 18.8s
# 422:	learn: 0.3063200	total: 5.39s	remaining: 18.8s
# 423:	learn: 0.3061287	total: 5.4s	remaining: 18.8s
# 424:	learn: 0.3058960	total: 5.42s	remaining: 18.8s
# 425:	learn: 0.3058371	total: 5.43s	remaining: 18.8s
# 426:	learn: 0.3057073	total: 5.44s	remaining: 18.8s
# 427:	learn: 0.3054820	total: 5.45s	remaining: 18.7s
# 428:	learn: 0.3052926	total: 5.46s	remaining: 18.7s
# 429:	learn: 0.3048358	total: 5.47s	remaining: 18.7s
# 430:	learn: 0.3047888	total: 5.48s	remaining: 18.7s
# 431:	learn: 0.3045705	total: 5.5s	remaining: 18.7s
# 432:	learn: 0.3043042	total: 5.51s	remaining: 18.7s
# 433:	learn: 0.3038350	total: 5.52s	remaining: 18.6s
# 434:	learn: 0.3036259	total: 5.53s	remaining: 18.6s
# 435:	learn: 0.3034381	total: 5.55s	remaining: 18.6s
# 436:	learn: 0.3032161	total: 5.56s	remaining: 18.6s
# 437:	learn: 0.3031312	total: 5.58s	remaining: 18.6s
# 438:	learn: 0.3031044	total: 5.59s	remaining: 18.6s
# 439:	learn: 0.3029925	total: 5.6s	remaining: 18.6s
# 440:	learn: 0.3026540	total: 5.61s	remaining: 18.6s
# 441:	learn: 0.3022231	total: 5.62s	remaining: 18.5s
# 442:	learn: 0.3021372	total: 5.63s	remaining: 18.5s
# 443:	learn: 0.3020166	total: 5.64s	remaining: 18.5s
# 444:	learn: 0.3017668	total: 5.66s	remaining: 18.5s
# 445:	learn: 0.3017119	total: 5.67s	remaining: 18.5s
# 446:	learn: 0.3012434	total: 5.68s	remaining: 18.5s
# 447:	learn: 0.3011228	total: 5.69s	remaining: 18.4s
# 448:	learn: 0.3009348	total: 5.7s	remaining: 18.4s
# 449:	learn: 0.3006009	total: 5.71s	remaining: 18.4s
# 450:	learn: 0.3004165	total: 5.72s	remaining: 18.4s
# 451:	learn: 0.3002904	total: 5.73s	remaining: 18.4s
# 452:	learn: 0.3000797	total: 5.75s	remaining: 18.4s
# 453:	learn: 0.2999521	total: 5.76s	remaining: 18.4s
# 454:	learn: 0.2998094	total: 5.78s	remaining: 18.3s
# 455:	learn: 0.2996810	total: 5.79s	remaining: 18.3s
# 456:	learn: 0.2994190	total: 5.8s	remaining: 18.3s
# 457:	learn: 0.2992192	total: 5.81s	remaining: 18.3s
# 458:	learn: 0.2990460	total: 5.83s	remaining: 18.3s
# 459:	learn: 0.2987477	total: 5.84s	remaining: 18.3s
# 460:	learn: 0.2985485	total: 5.85s	remaining: 18.3s
# 461:	learn: 0.2984405	total: 5.86s	remaining: 18.2s
# 462:	learn: 0.2982407	total: 5.87s	remaining: 18.2s
# 463:	learn: 0.2981235	total: 5.88s	remaining: 18.2s
# 464:	learn: 0.2979932	total: 5.89s	remaining: 18.2s
# 465:	learn: 0.2977489	total: 5.9s	remaining: 18.2s
# 466:	learn: 0.2974606	total: 5.92s	remaining: 18.2s
# 467:	learn: 0.2973039	total: 5.93s	remaining: 18.1s
# 468:	learn: 0.2970610	total: 5.94s	remaining: 18.1s
# 469:	learn: 0.2969813	total: 5.95s	remaining: 18.1s
# 470:	learn: 0.2966225	total: 5.96s	remaining: 18.1s
# 471:	learn: 0.2964806	total: 5.98s	remaining: 18.1s
# 472:	learn: 0.2963313	total: 5.99s	remaining: 18.1s
# 473:	learn: 0.2960659	total: 6s	remaining: 18.1s
# 474:	learn: 0.2959268	total: 6.02s	remaining: 18.1s
# 475:	learn: 0.2957702	total: 6.03s	remaining: 18s
# 476:	learn: 0.2956617	total: 6.04s	remaining: 18s
# 477:	learn: 0.2954832	total: 6.05s	remaining: 18s
# 478:	learn: 0.2953009	total: 6.06s	remaining: 18s
# 479:	learn: 0.2950194	total: 6.07s	remaining: 18s
# 480:	learn: 0.2947313	total: 6.09s	remaining: 18s
# 481:	learn: 0.2945359	total: 6.1s	remaining: 17.9s
# 482:	learn: 0.2943769	total: 6.11s	remaining: 17.9s
# 483:	learn: 0.2942240	total: 6.12s	remaining: 17.9s
# 484:	learn: 0.2939966	total: 6.13s	remaining: 17.9s
# 485:	learn: 0.2938090	total: 6.14s	remaining: 17.9s
# 486:	learn: 0.2936058	total: 6.15s	remaining: 17.9s
# 487:	learn: 0.2933450	total: 6.17s	remaining: 17.8s
# 488:	learn: 0.2931763	total: 6.18s	remaining: 17.8s
# 489:	learn: 0.2928860	total: 6.19s	remaining: 17.8s
# 490:	learn: 0.2928243	total: 6.21s	remaining: 17.8s
# 491:	learn: 0.2927268	total: 6.22s	remaining: 17.8s
# 492:	learn: 0.2924448	total: 6.23s	remaining: 17.8s
# 493:	learn: 0.2922756	total: 6.24s	remaining: 17.8s
# 494:	learn: 0.2918447	total: 6.25s	remaining: 17.8s
# 495:	learn: 0.2916047	total: 6.27s	remaining: 17.7s
# 496:	learn: 0.2913524	total: 6.28s	remaining: 17.7s
# 497:	learn: 0.2911246	total: 6.29s	remaining: 17.7s
# 498:	learn: 0.2909961	total: 6.3s	remaining: 17.7s
# 499:	learn: 0.2908279	total: 6.31s	remaining: 17.7s
# 500:	learn: 0.2906315	total: 6.33s	remaining: 17.7s
# 501:	learn: 0.2903141	total: 6.34s	remaining: 17.6s
# 502:	learn: 0.2900724	total: 6.35s	remaining: 17.6s
# 503:	learn: 0.2898008	total: 6.36s	remaining: 17.6s
# 504:	learn: 0.2895528	total: 6.37s	remaining: 17.6s
# 505:	learn: 0.2894040	total: 6.38s	remaining: 17.6s
# 506:	learn: 0.2889639	total: 6.4s	remaining: 17.6s
# 507:	learn: 0.2886628	total: 6.41s	remaining: 17.6s
# 508:	learn: 0.2884959	total: 6.43s	remaining: 17.6s
# 509:	learn: 0.2883933	total: 6.44s	remaining: 17.6s
# 510:	learn: 0.2882169	total: 6.45s	remaining: 17.5s
# 511:	learn: 0.2880139	total: 6.46s	remaining: 17.5s
# 512:	learn: 0.2878548	total: 6.47s	remaining: 17.5s
# 513:	learn: 0.2876120	total: 6.49s	remaining: 17.5s
# 514:	learn: 0.2874366	total: 6.51s	remaining: 17.5s
# 515:	learn: 0.2871135	total: 6.53s	remaining: 17.5s
# 516:	learn: 0.2870230	total: 6.54s	remaining: 17.5s
# 517:	learn: 0.2868818	total: 6.55s	remaining: 17.5s
# 518:	learn: 0.2866201	total: 6.57s	remaining: 17.5s
# 519:	learn: 0.2863932	total: 6.58s	remaining: 17.5s
# 520:	learn: 0.2862853	total: 6.59s	remaining: 17.4s
# 521:	learn: 0.2860247	total: 6.61s	remaining: 17.4s
# 522:	learn: 0.2859231	total: 6.62s	remaining: 17.4s
# 523:	learn: 0.2856945	total: 6.63s	remaining: 17.4s
# 524:	learn: 0.2853132	total: 6.64s	remaining: 17.4s
# 525:	learn: 0.2850285	total: 6.66s	remaining: 17.4s
# 526:	learn: 0.2849394	total: 6.67s	remaining: 17.4s
# 527:	learn: 0.2845542	total: 6.68s	remaining: 17.4s
# 528:	learn: 0.2845120	total: 6.69s	remaining: 17.3s
# 529:	learn: 0.2843742	total: 6.7s	remaining: 17.3s
# 530:	learn: 0.2841521	total: 6.71s	remaining: 17.3s
# 531:	learn: 0.2839578	total: 6.72s	remaining: 17.3s
# 532:	learn: 0.2837795	total: 6.74s	remaining: 17.3s
# 533:	learn: 0.2836501	total: 6.75s	remaining: 17.3s
# 534:	learn: 0.2835423	total: 6.76s	remaining: 17.2s
# 535:	learn: 0.2834400	total: 6.77s	remaining: 17.2s
# 536:	learn: 0.2832500	total: 6.78s	remaining: 17.2s
# 537:	learn: 0.2830082	total: 6.79s	remaining: 17.2s
# 538:	learn: 0.2828837	total: 6.81s	remaining: 17.2s
# 539:	learn: 0.2826874	total: 6.82s	remaining: 17.2s
# 540:	learn: 0.2824174	total: 6.83s	remaining: 17.2s
# 541:	learn: 0.2821882	total: 6.85s	remaining: 17.2s
# 542:	learn: 0.2820797	total: 6.86s	remaining: 17.1s
# 543:	learn: 0.2819826	total: 6.87s	remaining: 17.1s
# 544:	learn: 0.2816299	total: 6.88s	remaining: 17.1s
# 545:	learn: 0.2813651	total: 6.9s	remaining: 17.1s
# 546:	learn: 0.2811590	total: 6.91s	remaining: 17.1s
# 547:	learn: 0.2810248	total: 6.92s	remaining: 17.1s
# 548:	learn: 0.2808846	total: 6.93s	remaining: 17.1s
# 549:	learn: 0.2807994	total: 6.94s	remaining: 17s
# 550:	learn: 0.2806701	total: 6.95s	remaining: 17s
# 551:	learn: 0.2804416	total: 6.97s	remaining: 17s
# 552:	learn: 0.2803308	total: 6.98s	remaining: 17s
# 553:	learn: 0.2800719	total: 7s	remaining: 17s
# 554:	learn: 0.2798595	total: 7.01s	remaining: 17s
# 555:	learn: 0.2796937	total: 7.02s	remaining: 17s
# 556:	learn: 0.2793939	total: 7.04s	remaining: 17s
# 557:	learn: 0.2792227	total: 7.05s	remaining: 17s
# 558:	learn: 0.2791539	total: 7.06s	remaining: 16.9s
# 559:	learn: 0.2790602	total: 7.07s	remaining: 16.9s
# 560:	learn: 0.2788807	total: 7.09s	remaining: 16.9s
# 561:	learn: 0.2787168	total: 7.1s	remaining: 16.9s
# 562:	learn: 0.2784943	total: 7.11s	remaining: 16.9s
# 563:	learn: 0.2783089	total: 7.12s	remaining: 16.9s
# 564:	learn: 0.2782894	total: 7.13s	remaining: 16.9s
# 565:	learn: 0.2781434	total: 7.14s	remaining: 16.8s
# 566:	learn: 0.2779184	total: 7.15s	remaining: 16.8s
# 567:	learn: 0.2777434	total: 7.17s	remaining: 16.8s
# 568:	learn: 0.2776308	total: 7.18s	remaining: 16.8s
# 569:	learn: 0.2775154	total: 7.19s	remaining: 16.8s
# 570:	learn: 0.2773231	total: 7.2s	remaining: 16.8s
# 571:	learn: 0.2771072	total: 7.21s	remaining: 16.7s
# 572:	learn: 0.2770228	total: 7.23s	remaining: 16.7s
# 573:	learn: 0.2769363	total: 7.24s	remaining: 16.7s
# 574:	learn: 0.2767036	total: 7.25s	remaining: 16.7s
# 575:	learn: 0.2765817	total: 7.26s	remaining: 16.7s
# 576:	learn: 0.2764427	total: 7.29s	remaining: 16.7s
# 577:	learn: 0.2761479	total: 7.3s	remaining: 16.7s
# 578:	learn: 0.2760969	total: 7.32s	remaining: 16.7s
# 579:	learn: 0.2758742	total: 7.33s	remaining: 16.7s
# 580:	learn: 0.2757427	total: 7.34s	remaining: 16.7s
# 581:	learn: 0.2754798	total: 7.35s	remaining: 16.6s
# 582:	learn: 0.2754607	total: 7.36s	remaining: 16.6s
# 583:	learn: 0.2753772	total: 7.37s	remaining: 16.6s
# 584:	learn: 0.2752145	total: 7.38s	remaining: 16.6s
# 585:	learn: 0.2751897	total: 7.39s	remaining: 16.6s
# 586:	learn: 0.2750131	total: 7.41s	remaining: 16.6s
# 587:	learn: 0.2746821	total: 7.42s	remaining: 16.6s
# 588:	learn: 0.2746560	total: 7.43s	remaining: 16.5s
# 589:	learn: 0.2744709	total: 7.45s	remaining: 16.5s
# 590:	learn: 0.2744487	total: 7.46s	remaining: 16.5s
# 591:	learn: 0.2743851	total: 7.47s	remaining: 16.5s
# 592:	learn: 0.2741548	total: 7.49s	remaining: 16.5s
# 593:	learn: 0.2740591	total: 7.5s	remaining: 16.5s
# 594:	learn: 0.2740271	total: 7.51s	remaining: 16.5s
# 595:	learn: 0.2737342	total: 7.52s	remaining: 16.5s
# 596:	learn: 0.2734530	total: 7.53s	remaining: 16.4s
# 597:	learn: 0.2734024	total: 7.54s	remaining: 16.4s
# 598:	learn: 0.2732619	total: 7.55s	remaining: 16.4s
# 599:	learn: 0.2731680	total: 7.56s	remaining: 16.4s
# 600:	learn: 0.2728507	total: 7.58s	remaining: 16.4s
# 601:	learn: 0.2726685	total: 7.59s	remaining: 16.4s
# 602:	learn: 0.2723191	total: 7.6s	remaining: 16.3s
# 603:	learn: 0.2722847	total: 7.61s	remaining: 16.3s
# 604:	learn: 0.2721786	total: 7.62s	remaining: 16.3s
# 605:	learn: 0.2719443	total: 7.63s	remaining: 16.3s
# 606:	learn: 0.2717901	total: 7.65s	remaining: 16.3s
# 607:	learn: 0.2715820	total: 7.66s	remaining: 16.3s
# 608:	learn: 0.2715456	total: 7.68s	remaining: 16.3s
# 609:	learn: 0.2714615	total: 7.69s	remaining: 16.3s
# 610:	learn: 0.2712649	total: 7.7s	remaining: 16.2s
# 611:	learn: 0.2711824	total: 7.71s	remaining: 16.2s
# 612:	learn: 0.2708923	total: 7.72s	remaining: 16.2s
# 613:	learn: 0.2708150	total: 7.74s	remaining: 16.2s
# 614:	learn: 0.2707349	total: 7.75s	remaining: 16.2s
# 615:	learn: 0.2706201	total: 7.76s	remaining: 16.2s
# 616:	learn: 0.2703129	total: 7.77s	remaining: 16.2s
# 617:	learn: 0.2700166	total: 7.78s	remaining: 16.1s
# 618:	learn: 0.2697558	total: 7.79s	remaining: 16.1s
# 619:	learn: 0.2696273	total: 7.8s	remaining: 16.1s
# 620:	learn: 0.2692991	total: 7.82s	remaining: 16.1s
# 621:	learn: 0.2689872	total: 7.83s	remaining: 16.1s
# 622:	learn: 0.2689378	total: 7.84s	remaining: 16.1s
# 623:	learn: 0.2687842	total: 7.86s	remaining: 16.1s
# 624:	learn: 0.2686491	total: 7.87s	remaining: 16.1s
# 625:	learn: 0.2685944	total: 7.88s	remaining: 16s
# 626:	learn: 0.2683033	total: 7.9s	remaining: 16s
# 627:	learn: 0.2682332	total: 7.91s	remaining: 16s
# 628:	learn: 0.2681198	total: 7.92s	remaining: 16s
# 629:	learn: 0.2679386	total: 7.93s	remaining: 16s
# 630:	learn: 0.2677428	total: 7.94s	remaining: 16s
# 631:	learn: 0.2675198	total: 7.95s	remaining: 16s
# 632:	learn: 0.2674109	total: 7.97s	remaining: 15.9s
# 633:	learn: 0.2671917	total: 7.99s	remaining: 16s
# 634:	learn: 0.2671029	total: 8s	remaining: 15.9s
# 635:	learn: 0.2668898	total: 8.01s	remaining: 15.9s
# 636:	learn: 0.2667696	total: 8.03s	remaining: 15.9s
# 637:	learn: 0.2665776	total: 8.04s	remaining: 15.9s
# 638:	learn: 0.2664214	total: 8.05s	remaining: 15.9s
# 639:	learn: 0.2661780	total: 8.07s	remaining: 15.9s
# 640:	learn: 0.2660716	total: 8.08s	remaining: 15.9s
# 641:	learn: 0.2660582	total: 8.09s	remaining: 15.9s
# 642:	learn: 0.2659834	total: 8.1s	remaining: 15.8s
# 643:	learn: 0.2659569	total: 8.11s	remaining: 15.8s
# 644:	learn: 0.2657379	total: 8.13s	remaining: 15.8s
# 645:	learn: 0.2656438	total: 8.14s	remaining: 15.8s
# 646:	learn: 0.2656076	total: 8.15s	remaining: 15.8s
# 647:	learn: 0.2653939	total: 8.16s	remaining: 15.8s
# 648:	learn: 0.2651999	total: 8.17s	remaining: 15.8s
# 649:	learn: 0.2648799	total: 8.18s	remaining: 15.7s
# 650:	learn: 0.2646762	total: 8.2s	remaining: 15.7s
# 651:	learn: 0.2643606	total: 8.21s	remaining: 15.7s
# 652:	learn: 0.2642390	total: 8.22s	remaining: 15.7s
# 653:	learn: 0.2640157	total: 8.23s	remaining: 15.7s
# 654:	learn: 0.2637617	total: 8.24s	remaining: 15.7s
# 655:	learn: 0.2635413	total: 8.25s	remaining: 15.7s
# 656:	learn: 0.2633040	total: 8.27s	remaining: 15.6s
# 657:	learn: 0.2630382	total: 8.29s	remaining: 15.6s
# 658:	learn: 0.2630238	total: 8.3s	remaining: 15.6s
# 659:	learn: 0.2628418	total: 8.31s	remaining: 15.6s
# 660:	learn: 0.2626629	total: 8.32s	remaining: 15.6s
# 661:	learn: 0.2625457	total: 8.33s	remaining: 15.6s
# 662:	learn: 0.2622944	total: 8.35s	remaining: 15.6s
# 663:	learn: 0.2621802	total: 8.36s	remaining: 15.6s
# 664:	learn: 0.2620818	total: 8.37s	remaining: 15.5s
# 665:	learn: 0.2619371	total: 8.38s	remaining: 15.5s
# 666:	learn: 0.2617911	total: 8.39s	remaining: 15.5s
# 667:	learn: 0.2616495	total: 8.4s	remaining: 15.5s
# 668:	learn: 0.2614325	total: 8.41s	remaining: 15.5s
# 669:	learn: 0.2612725	total: 8.42s	remaining: 15.5s
# 670:	learn: 0.2612600	total: 8.44s	remaining: 15.5s
# 671:	learn: 0.2611799	total: 8.45s	remaining: 15.4s
# 672:	learn: 0.2608360	total: 8.46s	remaining: 15.4s
# 673:	learn: 0.2606485	total: 8.48s	remaining: 15.4s
# 674:	learn: 0.2605270	total: 8.49s	remaining: 15.4s
# 675:	learn: 0.2603447	total: 8.5s	remaining: 15.4s
# 676:	learn: 0.2601195	total: 8.52s	remaining: 15.4s
# 677:	learn: 0.2600160	total: 8.53s	remaining: 15.4s
# 678:	learn: 0.2599004	total: 8.54s	remaining: 15.4s
# 679:	learn: 0.2598182	total: 8.55s	remaining: 15.3s
# 680:	learn: 0.2597652	total: 8.56s	remaining: 15.3s
# 681:	learn: 0.2595708	total: 8.57s	remaining: 15.3s
# 682:	learn: 0.2593329	total: 8.59s	remaining: 15.3s
# 683:	learn: 0.2591879	total: 8.6s	remaining: 15.3s
# 684:	learn: 0.2590298	total: 8.61s	remaining: 15.3s
# 685:	learn: 0.2588848	total: 8.62s	remaining: 15.3s
# 686:	learn: 0.2587472	total: 8.63s	remaining: 15.2s
# 687:	learn: 0.2586399	total: 8.64s	remaining: 15.2s
# 688:	learn: 0.2584588	total: 8.66s	remaining: 15.2s
# 689:	learn: 0.2583369	total: 8.67s	remaining: 15.2s
# 690:	learn: 0.2579324	total: 8.68s	remaining: 15.2s
# 691:	learn: 0.2578313	total: 8.69s	remaining: 15.2s
# 692:	learn: 0.2577183	total: 8.71s	remaining: 15.2s
# 693:	learn: 0.2575825	total: 8.72s	remaining: 15.2s
# 694:	learn: 0.2574877	total: 8.73s	remaining: 15.1s
# 695:	learn: 0.2573753	total: 8.75s	remaining: 15.1s
# 696:	learn: 0.2571417	total: 8.76s	remaining: 15.1s
# 697:	learn: 0.2570727	total: 8.77s	remaining: 15.1s
# 698:	learn: 0.2568997	total: 8.78s	remaining: 15.1s
# 699:	learn: 0.2568361	total: 8.79s	remaining: 15.1s
# 700:	learn: 0.2566038	total: 8.81s	remaining: 15.1s
# 701:	learn: 0.2564696	total: 8.82s	remaining: 15s
# 702:	learn: 0.2564066	total: 8.83s	remaining: 15s
# 703:	learn: 0.2563119	total: 8.84s	remaining: 15s
# 704:	learn: 0.2561641	total: 8.85s	remaining: 15s
# 705:	learn: 0.2561127	total: 8.86s	remaining: 15s
# 706:	learn: 0.2559561	total: 8.88s	remaining: 15s
# 707:	learn: 0.2557481	total: 8.89s	remaining: 15s
# 708:	learn: 0.2557329	total: 8.9s	remaining: 15s
# 709:	learn: 0.2555632	total: 8.92s	remaining: 14.9s
# 710:	learn: 0.2553932	total: 8.93s	remaining: 14.9s
# 711:	learn: 0.2552908	total: 8.94s	remaining: 14.9s
# 712:	learn: 0.2551729	total: 8.95s	remaining: 14.9s
# 713:	learn: 0.2550869	total: 8.96s	remaining: 14.9s
# 714:	learn: 0.2550618	total: 8.98s	remaining: 14.9s
# 715:	learn: 0.2548591	total: 8.99s	remaining: 14.9s
# 716:	learn: 0.2547895	total: 9s	remaining: 14.8s
# 717:	learn: 0.2545572	total: 9.01s	remaining: 14.8s
# 718:	learn: 0.2544345	total: 9.04s	remaining: 14.8s
# 719:	learn: 0.2541821	total: 9.05s	remaining: 14.8s
# 720:	learn: 0.2540899	total: 9.06s	remaining: 14.8s
# 721:	learn: 0.2539193	total: 9.07s	remaining: 14.8s
# 722:	learn: 0.2536726	total: 9.08s	remaining: 14.8s
# 723:	learn: 0.2535082	total: 9.1s	remaining: 14.8s
# 724:	learn: 0.2533734	total: 9.11s	remaining: 14.8s
# 725:	learn: 0.2532638	total: 9.12s	remaining: 14.8s
# 726:	learn: 0.2531117	total: 9.14s	remaining: 14.7s
# 727:	learn: 0.2529476	total: 9.15s	remaining: 14.7s
# 728:	learn: 0.2527747	total: 9.16s	remaining: 14.7s
# 729:	learn: 0.2526143	total: 9.17s	remaining: 14.7s
# 730:	learn: 0.2525074	total: 9.19s	remaining: 14.7s
# 731:	learn: 0.2523665	total: 9.2s	remaining: 14.7s
# 732:	learn: 0.2522763	total: 9.21s	remaining: 14.7s
# 733:	learn: 0.2521759	total: 9.22s	remaining: 14.6s
# 734:	learn: 0.2520117	total: 9.23s	remaining: 14.6s
# 735:	learn: 0.2518869	total: 9.24s	remaining: 14.6s
# 736:	learn: 0.2517681	total: 9.26s	remaining: 14.6s
# 737:	learn: 0.2514867	total: 9.27s	remaining: 14.6s
# 738:	learn: 0.2514148	total: 9.28s	remaining: 14.6s
# 739:	learn: 0.2513608	total: 9.29s	remaining: 14.6s
# 740:	learn: 0.2512155	total: 9.31s	remaining: 14.6s
# 741:	learn: 0.2511007	total: 9.32s	remaining: 14.5s
# 742:	learn: 0.2509603	total: 9.34s	remaining: 14.5s
# 743:	learn: 0.2507663	total: 9.35s	remaining: 14.5s
# 744:	learn: 0.2506391	total: 9.36s	remaining: 14.5s
# 745:	learn: 0.2505631	total: 9.37s	remaining: 14.5s
# 746:	learn: 0.2503617	total: 9.39s	remaining: 14.5s
# 747:	learn: 0.2502521	total: 9.4s	remaining: 14.5s
# 748:	learn: 0.2500995	total: 9.41s	remaining: 14.5s
# 749:	learn: 0.2500079	total: 9.42s	remaining: 14.4s
# 750:	learn: 0.2498143	total: 9.43s	remaining: 14.4s
# 751:	learn: 0.2496782	total: 9.45s	remaining: 14.4s
# 752:	learn: 0.2495139	total: 9.46s	remaining: 14.4s
# 753:	learn: 0.2493085	total: 9.47s	remaining: 14.4s
# 754:	learn: 0.2492279	total: 9.48s	remaining: 14.4s
# 755:	learn: 0.2491317	total: 9.49s	remaining: 14.4s
# 756:	learn: 0.2490575	total: 9.5s	remaining: 14.4s
# 757:	learn: 0.2489770	total: 9.52s	remaining: 14.3s
# 758:	learn: 0.2487868	total: 9.53s	remaining: 14.3s
# 759:	learn: 0.2486779	total: 9.55s	remaining: 14.3s
# 760:	learn: 0.2486654	total: 9.56s	remaining: 14.3s
# 761:	learn: 0.2485576	total: 9.57s	remaining: 14.3s
# 762:	learn: 0.2483964	total: 9.59s	remaining: 14.3s
# 763:	learn: 0.2483111	total: 9.6s	remaining: 14.3s
# 764:	learn: 0.2480741	total: 9.61s	remaining: 14.3s
# 765:	learn: 0.2480027	total: 9.62s	remaining: 14.2s
# 766:	learn: 0.2478084	total: 9.63s	remaining: 14.2s
# 767:	learn: 0.2477030	total: 9.64s	remaining: 14.2s
# 768:	learn: 0.2475681	total: 9.66s	remaining: 14.2s
# 769:	learn: 0.2475265	total: 9.67s	remaining: 14.2s
# 770:	learn: 0.2474557	total: 9.68s	remaining: 14.2s
# 771:	learn: 0.2473775	total: 9.7s	remaining: 14.2s
# 772:	learn: 0.2472250	total: 9.71s	remaining: 14.2s
# 773:	learn: 0.2470427	total: 9.74s	remaining: 14.2s
# 774:	learn: 0.2468164	total: 9.76s	remaining: 14.2s
# 775:	learn: 0.2466803	total: 9.78s	remaining: 14.2s
# 776:	learn: 0.2464834	total: 9.79s	remaining: 14.2s
# 777:	learn: 0.2463465	total: 9.81s	remaining: 14.1s
# 778:	learn: 0.2462362	total: 9.82s	remaining: 14.1s
# 779:	learn: 0.2461422	total: 9.84s	remaining: 14.1s
# 780:	learn: 0.2459290	total: 9.85s	remaining: 14.1s
# 781:	learn: 0.2458552	total: 9.86s	remaining: 14.1s
# 782:	learn: 0.2456598	total: 9.87s	remaining: 14.1s
# 783:	learn: 0.2455335	total: 9.88s	remaining: 14.1s
# 784:	learn: 0.2454274	total: 9.89s	remaining: 14.1s
# 785:	learn: 0.2452462	total: 9.91s	remaining: 14s
# 786:	learn: 0.2450611	total: 9.92s	remaining: 14s
# 787:	learn: 0.2448242	total: 9.93s	remaining: 14s
# 788:	learn: 0.2447087	total: 9.94s	remaining: 14s
# 789:	learn: 0.2446232	total: 9.96s	remaining: 14s
# 790:	learn: 0.2445024	total: 9.97s	remaining: 14s
# 791:	learn: 0.2444664	total: 9.98s	remaining: 14s
# 792:	learn: 0.2443565	total: 9.99s	remaining: 14s
# 793:	learn: 0.2441485	total: 10s	remaining: 13.9s
# 794:	learn: 0.2439371	total: 10s	remaining: 13.9s
# 795:	learn: 0.2437888	total: 10s	remaining: 13.9s
# 796:	learn: 0.2436706	total: 10s	remaining: 13.9s
# 797:	learn: 0.2435239	total: 10.1s	remaining: 13.9s
# 798:	learn: 0.2434233	total: 10.1s	remaining: 13.9s
# 799:	learn: 0.2433139	total: 10.1s	remaining: 13.9s
# 800:	learn: 0.2432064	total: 10.1s	remaining: 13.8s
# 801:	learn: 0.2431245	total: 10.1s	remaining: 13.8s
# 802:	learn: 0.2429522	total: 10.1s	remaining: 13.8s
# 803:	learn: 0.2428250	total: 10.1s	remaining: 13.8s
# 804:	learn: 0.2427586	total: 10.1s	remaining: 13.8s
# 805:	learn: 0.2426318	total: 10.1s	remaining: 13.8s
# 806:	learn: 0.2424465	total: 10.2s	remaining: 13.8s
# 807:	learn: 0.2423259	total: 10.2s	remaining: 13.7s
# 808:	learn: 0.2421674	total: 10.2s	remaining: 13.7s
# 809:	learn: 0.2420862	total: 10.2s	remaining: 13.7s
# 810:	learn: 0.2417844	total: 10.2s	remaining: 13.7s
# 811:	learn: 0.2416644	total: 10.2s	remaining: 13.7s
# 812:	learn: 0.2415367	total: 10.2s	remaining: 13.7s
# 813:	learn: 0.2414045	total: 10.2s	remaining: 13.7s
# 814:	learn: 0.2411838	total: 10.3s	remaining: 13.7s
# 815:	learn: 0.2410539	total: 10.3s	remaining: 13.6s
# 816:	learn: 0.2409808	total: 10.3s	remaining: 13.6s
# 817:	learn: 0.2408634	total: 10.3s	remaining: 13.6s
# 818:	learn: 0.2407607	total: 10.3s	remaining: 13.6s
# 819:	learn: 0.2406030	total: 10.3s	remaining: 13.6s
# 820:	learn: 0.2405804	total: 10.3s	remaining: 13.6s
# 821:	learn: 0.2404577	total: 10.3s	remaining: 13.6s
# 822:	learn: 0.2402381	total: 10.4s	remaining: 13.6s
# 823:	learn: 0.2401558	total: 10.4s	remaining: 13.5s
# 824:	learn: 0.2401309	total: 10.4s	remaining: 13.5s
# 825:	learn: 0.2399846	total: 10.4s	remaining: 13.5s
# 826:	learn: 0.2399714	total: 10.4s	remaining: 13.5s
# 827:	learn: 0.2398777	total: 10.4s	remaining: 13.5s
# 828:	learn: 0.2396665	total: 10.4s	remaining: 13.5s
# 829:	learn: 0.2396140	total: 10.4s	remaining: 13.5s
# 830:	learn: 0.2395723	total: 10.5s	remaining: 13.5s
# 831:	learn: 0.2395219	total: 10.5s	remaining: 13.4s
# 832:	learn: 0.2394244	total: 10.5s	remaining: 13.4s
# 833:	learn: 0.2393269	total: 10.5s	remaining: 13.4s
# 834:	learn: 0.2391451	total: 10.5s	remaining: 13.4s
# 835:	learn: 0.2390424	total: 10.5s	remaining: 13.4s
# 836:	learn: 0.2389265	total: 10.5s	remaining: 13.4s
# 837:	learn: 0.2388201	total: 10.5s	remaining: 13.4s
# 838:	learn: 0.2386666	total: 10.6s	remaining: 13.3s
# 839:	learn: 0.2385340	total: 10.6s	remaining: 13.3s
# 840:	learn: 0.2384542	total: 10.6s	remaining: 13.3s
# 841:	learn: 0.2383372	total: 10.6s	remaining: 13.3s
# 842:	learn: 0.2382765	total: 10.6s	remaining: 13.3s
# 843:	learn: 0.2380302	total: 10.6s	remaining: 13.3s
# 844:	learn: 0.2378413	total: 10.6s	remaining: 13.3s
# 845:	learn: 0.2377564	total: 10.6s	remaining: 13.3s
# 846:	learn: 0.2375836	total: 10.7s	remaining: 13.2s
# 847:	learn: 0.2374716	total: 10.7s	remaining: 13.2s
# 848:	learn: 0.2373312	total: 10.7s	remaining: 13.2s
# 849:	learn: 0.2372314	total: 10.7s	remaining: 13.2s
# 850:	learn: 0.2371135	total: 10.7s	remaining: 13.2s
# 851:	learn: 0.2370544	total: 10.7s	remaining: 13.2s
# 852:	learn: 0.2370441	total: 10.7s	remaining: 13.2s
# 853:	learn: 0.2368826	total: 10.7s	remaining: 13.1s
# 854:	learn: 0.2367431	total: 10.8s	remaining: 13.1s
# 855:	learn: 0.2366623	total: 10.8s	remaining: 13.1s
# 856:	learn: 0.2364914	total: 10.8s	remaining: 13.1s
# 857:	learn: 0.2363611	total: 10.8s	remaining: 13.1s
# 858:	learn: 0.2362905	total: 10.8s	remaining: 13.1s
# 859:	learn: 0.2362068	total: 10.8s	remaining: 13.1s
# 860:	learn: 0.2361027	total: 10.8s	remaining: 13.1s
# 861:	learn: 0.2360738	total: 10.8s	remaining: 13s
# 862:	learn: 0.2359923	total: 10.8s	remaining: 13s
# 863:	learn: 0.2358352	total: 10.9s	remaining: 13s
# 864:	learn: 0.2357328	total: 10.9s	remaining: 13s
# 865:	learn: 0.2356269	total: 10.9s	remaining: 13s
# 866:	learn: 0.2355097	total: 10.9s	remaining: 13s
# 867:	learn: 0.2353629	total: 10.9s	remaining: 13s
# 868:	learn: 0.2352001	total: 10.9s	remaining: 13s
# 869:	learn: 0.2350795	total: 10.9s	remaining: 12.9s
# 870:	learn: 0.2350143	total: 10.9s	remaining: 12.9s
# 871:	learn: 0.2349266	total: 10.9s	remaining: 12.9s
# 872:	learn: 0.2347092	total: 11s	remaining: 12.9s
# 873:	learn: 0.2346423	total: 11s	remaining: 12.9s
# 874:	learn: 0.2345417	total: 11s	remaining: 12.9s
# 875:	learn: 0.2344869	total: 11s	remaining: 12.9s
# 876:	learn: 0.2343705	total: 11s	remaining: 12.8s
# 877:	learn: 0.2341881	total: 11s	remaining: 12.8s
# 878:	learn: 0.2341019	total: 11s	remaining: 12.8s
# 879:	learn: 0.2340182	total: 11.1s	remaining: 12.8s
# 880:	learn: 0.2339112	total: 11.1s	remaining: 12.8s
# 881:	learn: 0.2337814	total: 11.1s	remaining: 12.8s
# 882:	learn: 0.2337063	total: 11.1s	remaining: 12.8s
# 883:	learn: 0.2336406	total: 11.1s	remaining: 12.8s
# 884:	learn: 0.2335730	total: 11.1s	remaining: 12.7s
# 885:	learn: 0.2335049	total: 11.1s	remaining: 12.7s
# 886:	learn: 0.2332877	total: 11.1s	remaining: 12.7s
# 887:	learn: 0.2331353	total: 11.1s	remaining: 12.7s
# 888:	learn: 0.2330676	total: 11.2s	remaining: 12.7s
# 889:	learn: 0.2329350	total: 11.2s	remaining: 12.7s
# 890:	learn: 0.2328325	total: 11.2s	remaining: 12.7s
# 891:	learn: 0.2326301	total: 11.2s	remaining: 12.7s
# 892:	learn: 0.2324949	total: 11.2s	remaining: 12.6s
# 893:	learn: 0.2323671	total: 11.2s	remaining: 12.6s
# 894:	learn: 0.2322898	total: 11.2s	remaining: 12.6s
# 895:	learn: 0.2320758	total: 11.2s	remaining: 12.6s
# 896:	learn: 0.2320471	total: 11.3s	remaining: 12.6s
# 897:	learn: 0.2319739	total: 11.3s	remaining: 12.6s
# 898:	learn: 0.2319316	total: 11.3s	remaining: 12.6s
# 899:	learn: 0.2319195	total: 11.3s	remaining: 12.5s
# 900:	learn: 0.2318242	total: 11.3s	remaining: 12.5s
# 901:	learn: 0.2317081	total: 11.3s	remaining: 12.5s
# 902:	learn: 0.2316289	total: 11.3s	remaining: 12.5s
# 903:	learn: 0.2315561	total: 11.3s	remaining: 12.5s
# 904:	learn: 0.2314677	total: 11.3s	remaining: 12.5s
# 905:	learn: 0.2313279	total: 11.4s	remaining: 12.5s
# 906:	learn: 0.2312650	total: 11.4s	remaining: 12.4s
# 907:	learn: 0.2311285	total: 11.4s	remaining: 12.4s
# 908:	learn: 0.2310557	total: 11.4s	remaining: 12.4s
# 909:	learn: 0.2309851	total: 11.4s	remaining: 12.4s
# 910:	learn: 0.2308666	total: 11.4s	remaining: 12.4s
# 911:	learn: 0.2307739	total: 11.4s	remaining: 12.4s
# 912:	learn: 0.2307625	total: 11.5s	remaining: 12.4s
# 913:	learn: 0.2306768	total: 11.5s	remaining: 12.4s
# 914:	learn: 0.2306131	total: 11.5s	remaining: 12.4s
# 915:	learn: 0.2305361	total: 11.5s	remaining: 12.4s
# 916:	learn: 0.2304539	total: 11.5s	remaining: 12.3s
# 917:	learn: 0.2303718	total: 11.5s	remaining: 12.3s
# 918:	learn: 0.2303098	total: 11.5s	remaining: 12.3s
# 919:	learn: 0.2302526	total: 11.6s	remaining: 12.3s
# 920:	learn: 0.2301524	total: 11.6s	remaining: 12.3s
# 921:	learn: 0.2300711	total: 11.6s	remaining: 12.3s
# 922:	learn: 0.2299057	total: 11.6s	remaining: 12.3s
# 923:	learn: 0.2298582	total: 11.6s	remaining: 12.3s
# 924:	learn: 0.2297625	total: 11.6s	remaining: 12.2s
# 925:	learn: 0.2297027	total: 11.6s	remaining: 12.2s
# 926:	learn: 0.2296843	total: 11.6s	remaining: 12.2s
# 927:	learn: 0.2295950	total: 11.7s	remaining: 12.2s
# 928:	learn: 0.2295383	total: 11.7s	remaining: 12.2s
# 929:	learn: 0.2295076	total: 11.7s	remaining: 12.2s
# ...
# 1597:	learn: 0.1772982	total: 19.8s	remaining: 3.74s
# 1598:	learn: 0.1772280	total: 19.8s	remaining: 3.73s
# 1599:	learn: 0.1771948	total: 19.8s	remaining: 3.72s
# 1600:	learn: 0.1771569	total: 19.8s	remaining: 3.71s
# 1601:	learn: 0.1770993	total: 19.9s	remaining: 3.69s
# 1602:	learn: 0.1770596	total: 19.9s	remaining: 3.68s
# 1603:	learn: 0.1770226	total: 19.9s	remaining: 3.67s
# 1604:	learn: 0.1769253	total: 19.9s	remaining: 3.65s
# 1605:	learn: 0.1768222	total: 19.9s	remaining: 3.64s
# 1606:	learn: 0.1767799	total: 19.9s	remaining: 3.63s
# 1607:	learn: 0.1766826	total: 19.9s	remaining: 3.62s
# 1608:	learn: 0.1766143	total: 19.9s	remaining: 3.61s
# 1609:	learn: 0.1765441	total: 20s	remaining: 3.59s
# 1610:	learn: 0.1765274	total: 20s	remaining: 3.58s
# 1611:	learn: 0.1764510	total: 20s	remaining: 3.57s
# 1612:	learn: 0.1764091	total: 20s	remaining: 3.56s
# 1613:	learn: 0.1762738	total: 20s	remaining: 3.54s
# 1614:	learn: 0.1762325	total: 20s	remaining: 3.53s
# 1615:	learn: 0.1762047	total: 20s	remaining: 3.52s
# 1616:	learn: 0.1761810	total: 20s	remaining: 3.51s
# 1617:	learn: 0.1761024	total: 20.1s	remaining: 3.49s
# 1618:	learn: 0.1760367	total: 20.1s	remaining: 3.48s
# 1619:	learn: 0.1760128	total: 20.1s	remaining: 3.47s
# 1620:	learn: 0.1759698	total: 20.1s	remaining: 3.46s
# 1621:	learn: 0.1759285	total: 20.1s	remaining: 3.44s
# 1622:	learn: 0.1758352	total: 20.1s	remaining: 3.43s
# 1623:	learn: 0.1757898	total: 20.1s	remaining: 3.42s
# 1624:	learn: 0.1757424	total: 20.1s	remaining: 3.41s
# 1625:	learn: 0.1757061	total: 20.2s	remaining: 3.4s
# 1626:	learn: 0.1756617	total: 20.2s	remaining: 3.38s
# 1627:	learn: 0.1756054	total: 20.2s	remaining: 3.37s
# 1628:	learn: 0.1755480	total: 20.2s	remaining: 3.36s
# 1629:	learn: 0.1754794	total: 20.2s	remaining: 3.35s
# 1630:	learn: 0.1754327	total: 20.2s	remaining: 3.33s
# 1631:	learn: 0.1753528	total: 20.2s	remaining: 3.32s
# 1632:	learn: 0.1752754	total: 20.2s	remaining: 3.31s
# 1633:	learn: 0.1751899	total: 20.2s	remaining: 3.3s
# 1634:	learn: 0.1751143	total: 20.3s	remaining: 3.28s
# 1635:	learn: 0.1750948	total: 20.3s	remaining: 3.27s
# 1636:	learn: 0.1750533	total: 20.3s	remaining: 3.26s
# 1637:	learn: 0.1750245	total: 20.3s	remaining: 3.25s
# 1638:	learn: 0.1749363	total: 20.3s	remaining: 3.23s
# 1639:	learn: 0.1748954	total: 20.3s	remaining: 3.22s
# 1640:	learn: 0.1748839	total: 20.3s	remaining: 3.21s
# 1641:	learn: 0.1748230	total: 20.4s	remaining: 3.2s
# 1642:	learn: 0.1747977	total: 20.4s	remaining: 3.19s
# 1643:	learn: 0.1746677	total: 20.4s	remaining: 3.17s
# 1644:	learn: 0.1745824	total: 20.4s	remaining: 3.16s
# 1645:	learn: 0.1745476	total: 20.4s	remaining: 3.15s
# 1646:	learn: 0.1744904	total: 20.4s	remaining: 3.13s
# 1647:	learn: 0.1744556	total: 20.4s	remaining: 3.12s
# 1648:	learn: 0.1744219	total: 20.4s	remaining: 3.11s
# 1649:	learn: 0.1743457	total: 20.4s	remaining: 3.1s
# 1650:	learn: 0.1742617	total: 20.5s	remaining: 3.08s
# 1651:	learn: 0.1741823	total: 20.5s	remaining: 3.07s
# 1652:	learn: 0.1741578	total: 20.5s	remaining: 3.06s
# 1653:	learn: 0.1741459	total: 20.5s	remaining: 3.05s
# 1654:	learn: 0.1740449	total: 20.5s	remaining: 3.04s
# 1655:	learn: 0.1740122	total: 20.5s	remaining: 3.02s
# 1656:	learn: 0.1740008	total: 20.5s	remaining: 3.01s
# 1657:	learn: 0.1739253	total: 20.5s	remaining: 3s
# 1658:	learn: 0.1738525	total: 20.6s	remaining: 2.99s
# 1659:	learn: 0.1738280	total: 20.6s	remaining: 2.97s
# 1660:	learn: 0.1737987	total: 20.6s	remaining: 2.96s
# 1661:	learn: 0.1737237	total: 20.6s	remaining: 2.95s
# 1662:	learn: 0.1736787	total: 20.6s	remaining: 2.94s
# 1663:	learn: 0.1735998	total: 20.6s	remaining: 2.92s
# 1664:	learn: 0.1735489	total: 20.6s	remaining: 2.91s
# 1665:	learn: 0.1735169	total: 20.6s	remaining: 2.9s
# 1666:	learn: 0.1735049	total: 20.6s	remaining: 2.89s
# 1667:	learn: 0.1734271	total: 20.7s	remaining: 2.87s
# 1668:	learn: 0.1733839	total: 20.7s	remaining: 2.86s
# 1669:	learn: 0.1733420	total: 20.7s	remaining: 2.85s
# 1670:	learn: 0.1733258	total: 20.7s	remaining: 2.84s
# 1671:	learn: 0.1732514	total: 20.7s	remaining: 2.82s
# 1672:	learn: 0.1731836	total: 20.7s	remaining: 2.81s
# 1673:	learn: 0.1731130	total: 20.7s	remaining: 2.8s
# 1674:	learn: 0.1730586	total: 20.7s	remaining: 2.79s
# 1675:	learn: 0.1729866	total: 20.8s	remaining: 2.77s
# 1676:	learn: 0.1729609	total: 20.8s	remaining: 2.76s
# 1677:	learn: 0.1729181	total: 20.8s	remaining: 2.75s
# 1678:	learn: 0.1728429	total: 20.8s	remaining: 2.74s
# 1679:	learn: 0.1727477	total: 20.8s	remaining: 2.73s
# 1680:	learn: 0.1726978	total: 20.8s	remaining: 2.71s
# 1681:	learn: 0.1726372	total: 20.8s	remaining: 2.7s
# 1682:	learn: 0.1725555	total: 20.8s	remaining: 2.69s
# 1683:	learn: 0.1725061	total: 20.9s	remaining: 2.67s
# 1684:	learn: 0.1724082	total: 20.9s	remaining: 2.66s
# 1685:	learn: 0.1723458	total: 20.9s	remaining: 2.65s
# 1686:	learn: 0.1723089	total: 20.9s	remaining: 2.64s
# 1687:	learn: 0.1722862	total: 20.9s	remaining: 2.63s
# 1688:	learn: 0.1721746	total: 20.9s	remaining: 2.61s
# 1689:	learn: 0.1721040	total: 20.9s	remaining: 2.6s
# 1690:	learn: 0.1720867	total: 21s	remaining: 2.59s
# 1691:	learn: 0.1720547	total: 21s	remaining: 2.58s
# 1692:	learn: 0.1719777	total: 21s	remaining: 2.56s
# 1693:	learn: 0.1719690	total: 21s	remaining: 2.55s
# 1694:	learn: 0.1719011	total: 21s	remaining: 2.54s
# 1695:	learn: 0.1718891	total: 21s	remaining: 2.53s
# 1696:	learn: 0.1718334	total: 21s	remaining: 2.52s
# 1697:	learn: 0.1717875	total: 21s	remaining: 2.5s
# 1698:	learn: 0.1717261	total: 21.1s	remaining: 2.49s
# 1699:	learn: 0.1716522	total: 21.1s	remaining: 2.48s
# 1700:	learn: 0.1715945	total: 21.1s	remaining: 2.46s
# 1701:	learn: 0.1714742	total: 21.1s	remaining: 2.45s
# 1702:	learn: 0.1714371	total: 21.1s	remaining: 2.44s
# 1703:	learn: 0.1714020	total: 21.1s	remaining: 2.43s
# 1704:	learn: 0.1713475	total: 21.1s	remaining: 2.42s
# 1705:	learn: 0.1713032	total: 21.1s	remaining: 2.4s
# 1706:	learn: 0.1712325	total: 21.2s	remaining: 2.39s
# 1707:	learn: 0.1712138	total: 21.2s	remaining: 2.38s
# 1708:	learn: 0.1711915	total: 21.2s	remaining: 2.37s
# 1709:	learn: 0.1711734	total: 21.2s	remaining: 2.35s
# 1710:	learn: 0.1711164	total: 21.2s	remaining: 2.34s
# 1711:	learn: 0.1710313	total: 21.2s	remaining: 2.33s
# 1712:	learn: 0.1709999	total: 21.2s	remaining: 2.32s
# 1713:	learn: 0.1709678	total: 21.2s	remaining: 2.3s
# 1714:	learn: 0.1709426	total: 21.2s	remaining: 2.29s
# 1715:	learn: 0.1709116	total: 21.3s	remaining: 2.28s
# 1716:	learn: 0.1707964	total: 21.3s	remaining: 2.27s
# 1717:	learn: 0.1707474	total: 21.3s	remaining: 2.25s
# 1718:	learn: 0.1707168	total: 21.3s	remaining: 2.24s
# 1719:	learn: 0.1706943	total: 21.3s	remaining: 2.23s
# 1720:	learn: 0.1706158	total: 21.3s	remaining: 2.22s
# 1721:	learn: 0.1705829	total: 21.3s	remaining: 2.21s
# 1722:	learn: 0.1705585	total: 21.3s	remaining: 2.19s
# 1723:	learn: 0.1704677	total: 21.4s	remaining: 2.18s
# 1724:	learn: 0.1704019	total: 21.4s	remaining: 2.17s
# 1725:	learn: 0.1703632	total: 21.4s	remaining: 2.15s
# 1726:	learn: 0.1703528	total: 21.4s	remaining: 2.14s
# 1727:	learn: 0.1702679	total: 21.4s	remaining: 2.13s
# 1728:	learn: 0.1702470	total: 21.4s	remaining: 2.12s
# 1729:	learn: 0.1702241	total: 21.4s	remaining: 2.1s
# 1730:	learn: 0.1701553	total: 21.4s	remaining: 2.09s
# 1731:	learn: 0.1701292	total: 21.5s	remaining: 2.08s
# 1732:	learn: 0.1701155	total: 21.5s	remaining: 2.07s
# 1733:	learn: 0.1700734	total: 21.5s	remaining: 2.06s
# 1734:	learn: 0.1700528	total: 21.5s	remaining: 2.04s
# 1735:	learn: 0.1699714	total: 21.5s	remaining: 2.03s
# 1736:	learn: 0.1699594	total: 21.5s	remaining: 2.02s
# 1737:	learn: 0.1699112	total: 21.5s	remaining: 2.01s
# 1738:	learn: 0.1698637	total: 21.5s	remaining: 1.99s
# 1739:	learn: 0.1698383	total: 21.6s	remaining: 1.98s
# 1740:	learn: 0.1698245	total: 21.6s	remaining: 1.97s
# 1741:	learn: 0.1697619	total: 21.6s	remaining: 1.96s
# 1742:	learn: 0.1697072	total: 21.6s	remaining: 1.94s
# 1743:	learn: 0.1696739	total: 21.6s	remaining: 1.93s
# 1744:	learn: 0.1696205	total: 21.6s	remaining: 1.92s
# 1745:	learn: 0.1695852	total: 21.6s	remaining: 1.91s
# 1746:	learn: 0.1695457	total: 21.6s	remaining: 1.89s
# 1747:	learn: 0.1694763	total: 21.6s	remaining: 1.88s
# 1748:	learn: 0.1694324	total: 21.7s	remaining: 1.87s
# 1749:	learn: 0.1693682	total: 21.7s	remaining: 1.86s
# 1750:	learn: 0.1693388	total: 21.7s	remaining: 1.84s
# 1751:	learn: 0.1692807	total: 21.7s	remaining: 1.83s
# 1752:	learn: 0.1691932	total: 21.7s	remaining: 1.82s
# 1753:	learn: 0.1691739	total: 21.7s	remaining: 1.81s
# 1754:	learn: 0.1691468	total: 21.7s	remaining: 1.79s
# 1755:	learn: 0.1691294	total: 21.7s	remaining: 1.78s
# 1756:	learn: 0.1690828	total: 21.8s	remaining: 1.77s
# 1757:	learn: 0.1690520	total: 21.8s	remaining: 1.76s
# 1758:	learn: 0.1689760	total: 21.8s	remaining: 1.75s
# 1759:	learn: 0.1689259	total: 21.8s	remaining: 1.73s
# 1760:	learn: 0.1688485	total: 21.8s	remaining: 1.72s
# 1761:	learn: 0.1687874	total: 21.8s	remaining: 1.71s
# 1762:	learn: 0.1687367	total: 21.8s	remaining: 1.7s
# 1763:	learn: 0.1686766	total: 21.8s	remaining: 1.68s
# 1764:	learn: 0.1686235	total: 21.9s	remaining: 1.67s
# 1765:	learn: 0.1686024	total: 21.9s	remaining: 1.66s
# 1766:	learn: 0.1685551	total: 21.9s	remaining: 1.65s
# 1767:	learn: 0.1685271	total: 21.9s	remaining: 1.63s
# 1768:	learn: 0.1684984	total: 21.9s	remaining: 1.62s
# 1769:	learn: 0.1684112	total: 21.9s	remaining: 1.61s
# 1770:	learn: 0.1682473	total: 21.9s	remaining: 1.6s
# 1771:	learn: 0.1681972	total: 21.9s	remaining: 1.58s
# 1772:	learn: 0.1681662	total: 21.9s	remaining: 1.57s
# 1773:	learn: 0.1680968	total: 22s	remaining: 1.56s
# 1774:	learn: 0.1680518	total: 22s	remaining: 1.55s
# 1775:	learn: 0.1679772	total: 22s	remaining: 1.53s
# 1776:	learn: 0.1678814	total: 22s	remaining: 1.52s
# 1777:	learn: 0.1678219	total: 22s	remaining: 1.51s
# 1778:	learn: 0.1677793	total: 22s	remaining: 1.5s
# 1779:	learn: 0.1677378	total: 22s	remaining: 1.49s
# 1780:	learn: 0.1675465	total: 22s	remaining: 1.47s
# 1781:	learn: 0.1675264	total: 22.1s	remaining: 1.46s
# 1782:	learn: 0.1674945	total: 22.1s	remaining: 1.45s
# 1783:	learn: 0.1674724	total: 22.1s	remaining: 1.44s
# 1784:	learn: 0.1673854	total: 22.1s	remaining: 1.42s
# 1785:	learn: 0.1673639	total: 22.1s	remaining: 1.41s
# 1786:	learn: 0.1673106	total: 22.1s	remaining: 1.4s
# 1787:	learn: 0.1672692	total: 22.1s	remaining: 1.39s
# 1788:	learn: 0.1672390	total: 22.1s	remaining: 1.37s
# 1789:	learn: 0.1671880	total: 22.2s	remaining: 1.36s
# 1790:	learn: 0.1671658	total: 22.2s	remaining: 1.35s
# 1791:	learn: 0.1671023	total: 22.2s	remaining: 1.34s
# 1792:	learn: 0.1670470	total: 22.2s	remaining: 1.32s
# 1793:	learn: 0.1669734	total: 22.2s	remaining: 1.31s
# 1794:	learn: 0.1669378	total: 22.2s	remaining: 1.3s
# 1795:	learn: 0.1668583	total: 22.2s	remaining: 1.29s
# 1796:	learn: 0.1667122	total: 22.2s	remaining: 1.27s
# 1797:	learn: 0.1666701	total: 22.3s	remaining: 1.26s
# 1798:	learn: 0.1666309	total: 22.3s	remaining: 1.25s
# 1799:	learn: 0.1665752	total: 22.3s	remaining: 1.24s
# 1800:	learn: 0.1665505	total: 22.3s	remaining: 1.23s
# 1801:	learn: 0.1665230	total: 22.3s	remaining: 1.21s
# 1802:	learn: 0.1664493	total: 22.3s	remaining: 1.2s
# 1803:	learn: 0.1663701	total: 22.3s	remaining: 1.19s
# 1804:	learn: 0.1662202	total: 22.3s	remaining: 1.18s
# 1805:	learn: 0.1661988	total: 22.4s	remaining: 1.16s
# 1806:	learn: 0.1661455	total: 22.4s	remaining: 1.15s
# 1807:	learn: 0.1661040	total: 22.4s	remaining: 1.14s
# 1808:	learn: 0.1660720	total: 22.4s	remaining: 1.13s
# 1809:	learn: 0.1660095	total: 22.4s	remaining: 1.11s
# 1810:	learn: 0.1659500	total: 22.4s	remaining: 1.1s
# 1811:	learn: 0.1658886	total: 22.4s	remaining: 1.09s
# 1812:	learn: 0.1658628	total: 22.4s	remaining: 1.08s
# 1813:	learn: 0.1658232	total: 22.4s	remaining: 1.06s
# 1814:	learn: 0.1658087	total: 22.5s	remaining: 1.05s
# 1815:	learn: 0.1657370	total: 22.5s	remaining: 1.04s
# 1816:	learn: 0.1657146	total: 22.5s	remaining: 1.03s
# 1817:	learn: 0.1656698	total: 22.5s	remaining: 1.01s
# 1818:	learn: 0.1656352	total: 22.5s	remaining: 1s
# 1819:	learn: 0.1655854	total: 22.5s	remaining: 990ms
# 1820:	learn: 0.1655274	total: 22.5s	remaining: 977ms
# 1821:	learn: 0.1655018	total: 22.5s	remaining: 965ms
# 1822:	learn: 0.1654587	total: 22.6s	remaining: 953ms
# 1823:	learn: 0.1653802	total: 22.6s	remaining: 941ms
# 1824:	learn: 0.1653075	total: 22.6s	remaining: 928ms
# 1825:	learn: 0.1652700	total: 22.6s	remaining: 916ms
# 1826:	learn: 0.1652201	total: 22.6s	remaining: 903ms
# 1827:	learn: 0.1652014	total: 22.6s	remaining: 891ms
# 1828:	learn: 0.1651448	total: 22.6s	remaining: 879ms
# 1829:	learn: 0.1651401	total: 22.6s	remaining: 866ms
# 1830:	learn: 0.1651074	total: 22.7s	remaining: 854ms
# 1831:	learn: 0.1650862	total: 22.7s	remaining: 841ms
# 1832:	learn: 0.1650655	total: 22.7s	remaining: 829ms
# 1833:	learn: 0.1650373	total: 22.7s	remaining: 816ms
# 1834:	learn: 0.1650057	total: 22.7s	remaining: 804ms
# 1835:	learn: 0.1649831	total: 22.7s	remaining: 792ms
# 1836:	learn: 0.1649302	total: 22.7s	remaining: 779ms
# 1837:	learn: 0.1648913	total: 22.7s	remaining: 767ms
# 1838:	learn: 0.1648599	total: 22.7s	remaining: 754ms
# 1839:	learn: 0.1648214	total: 22.8s	remaining: 742ms
# 1840:	learn: 0.1647979	total: 22.8s	remaining: 730ms
# 1841:	learn: 0.1647356	total: 22.8s	remaining: 718ms
# 1842:	learn: 0.1646825	total: 22.8s	remaining: 705ms
# 1843:	learn: 0.1646299	total: 22.8s	remaining: 693ms
# 1844:	learn: 0.1646031	total: 22.8s	remaining: 680ms
# 1845:	learn: 0.1645194	total: 22.8s	remaining: 668ms
# 1846:	learn: 0.1644967	total: 22.8s	remaining: 656ms
# 1847:	learn: 0.1644696	total: 22.9s	remaining: 643ms
# 1848:	learn: 0.1644453	total: 22.9s	remaining: 631ms
# 1849:	learn: 0.1643906	total: 22.9s	remaining: 618ms
# 1850:	learn: 0.1643736	total: 22.9s	remaining: 606ms
# 1851:	learn: 0.1643042	total: 22.9s	remaining: 594ms
# 1852:	learn: 0.1642807	total: 22.9s	remaining: 581ms
# 1853:	learn: 0.1642324	total: 22.9s	remaining: 569ms
# 1854:	learn: 0.1642145	total: 22.9s	remaining: 556ms
# 1855:	learn: 0.1641987	total: 22.9s	remaining: 544ms
# 1856:	learn: 0.1641385	total: 23s	remaining: 532ms
# 1857:	learn: 0.1641229	total: 23s	remaining: 519ms
# 1858:	learn: 0.1640384	total: 23s	remaining: 507ms
# 1859:	learn: 0.1639655	total: 23s	remaining: 495ms
# 1860:	learn: 0.1638914	total: 23s	remaining: 482ms
# 1861:	learn: 0.1638762	total: 23s	remaining: 470ms
# 1862:	learn: 0.1638488	total: 23s	remaining: 458ms
# 1863:	learn: 0.1638164	total: 23.1s	remaining: 445ms
# 1864:	learn: 0.1638038	total: 23.1s	remaining: 433ms
# 1865:	learn: 0.1637282	total: 23.1s	remaining: 420ms
# 1866:	learn: 0.1636652	total: 23.1s	remaining: 408ms
# 1867:	learn: 0.1636045	total: 23.1s	remaining: 396ms
# 1868:	learn: 0.1635918	total: 23.1s	remaining: 383ms
# 1869:	learn: 0.1635617	total: 23.1s	remaining: 371ms
# 1870:	learn: 0.1634969	total: 23.1s	remaining: 359ms
# 1871:	learn: 0.1634615	total: 23.1s	remaining: 346ms
# 1872:	learn: 0.1634299	total: 23.2s	remaining: 334ms
# 1873:	learn: 0.1633525	total: 23.2s	remaining: 322ms
# 1874:	learn: 0.1632247	total: 23.2s	remaining: 309ms
# 1875:	learn: 0.1631727	total: 23.2s	remaining: 297ms
# 1876:	learn: 0.1631237	total: 23.2s	remaining: 284ms
# 1877:	learn: 0.1631077	total: 23.2s	remaining: 272ms
# 1878:	learn: 0.1630763	total: 23.2s	remaining: 260ms
# 1879:	learn: 0.1630376	total: 23.3s	remaining: 247ms
# 1880:	learn: 0.1629824	total: 23.3s	remaining: 235ms
# 1881:	learn: 0.1629363	total: 23.3s	remaining: 223ms
# 1882:	learn: 0.1628912	total: 23.3s	remaining: 210ms
# 1883:	learn: 0.1628655	total: 23.3s	remaining: 198ms
# 1884:	learn: 0.1628070	total: 23.3s	remaining: 185ms
# 1885:	learn: 0.1627099	total: 23.3s	remaining: 173ms
# 1886:	learn: 0.1626794	total: 23.3s	remaining: 161ms
# 1887:	learn: 0.1626390	total: 23.3s	remaining: 148ms
# 1888:	learn: 0.1625514	total: 23.4s	remaining: 136ms
# 1889:	learn: 0.1624882	total: 23.4s	remaining: 124ms
# 1890:	learn: 0.1624358	total: 23.4s	remaining: 111ms
# 1891:	learn: 0.1623819	total: 23.4s	remaining: 98.9ms
# 1892:	learn: 0.1623402	total: 23.4s	remaining: 86.6ms
# 1893:	learn: 0.1623058	total: 23.4s	remaining: 74.2ms
# 1894:	learn: 0.1622674	total: 23.4s	remaining: 61.8ms
# 1895:	learn: 0.1622357	total: 23.4s	remaining: 49.5ms
# 1896:	learn: 0.1621638	total: 23.5s	remaining: 37.1ms
# 1897:	learn: 0.1621086	total: 23.5s	remaining: 24.7ms
# 1898:	learn: 0.1620658	total: 23.5s	remaining: 12.4ms
# 1899:	learn: 0.1620416	total: 23.5s	remaining: 0us

# %% [markdown]
# pred_train=lgb_model.best_estimator_.predict(X_train)
# pred_test=lgb_model.best_estimator_.predict(X_test)

# %%
print('(Test) CatBoost Regression RMSLE:', rmsle(y_test, pred_test, True))
print('(Train) CatBoost Regression RMSLE:', rmsle(y_train, pred_train, True))

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
#
# # sorted(zip(clf.feature_importances_, X.columns), reverse=True)
# feature_imp = pd.DataFrame(sorted(zip(lgb_model.best_estimator_.feature_importances_,X_train.columns)), columns=['Value','Feature'])
#
# plt.figure(figsize=(20, 10))
# sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
# plt.title('LightGBM Features (avg over folds)')
# plt.tight_layout()
# plt.show()
# plt.savefig('lgbm_importances-01.png')

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### Submission Preparation

# %%
full_test_path = r"SeoulBikeDataTestFull.csv"

# %%
full_test = pd.read_csv(full_test_path)

# %%
test = df_test.copy()

# %%
test['Year'] = df_test['Date'].dt.year.astype('int')
test['Week'] = df_test['Date'].dt.isocalendar().week.astype('int')
test['Month'] = df_test['Date'].dt.month.astype('int') 
test['WeekDay'] = df_test['Date'].dt.weekday.astype('int')

# %%
#test.y.value_counts()

# %%
test.columns

# %% [markdown]
# ## Test Data Procc

# %%
map_data_series(test,'Functioning Day',['Yes','No'],[1,0])

# %%
map_data_series(test,'Holiday',['Holiday','No Holiday'],[1,0])

# %%
map_data_series(test,'Seasons',['Winter','Spring','Summer','Autumn'],[0,1,2,3])

# %%
new_feature_data_series(test,['Hour','Functioning Day'],dead_hour_grad_2,'Dead_hour')
new_feature_data_series(test,['Hour','Functioning Day'],rush_hour_grad,'Rush_hour')

# %%
new_feature_data_series(test,['Hour'],day_night,'day_night')
new_feature_data_series(test,['Humidity(%)'],lambda df : 0 if (df['Humidity(%)'] <= 70) else 1,'Humidity_high')
new_feature_data_series(test,['Temperature(C)'],lambda df : 0 if (df['Temperature(C)'] <= 35) else 1,'Temperature_high')

# %%
new_feature_data_series(test,['Humidity(%)','Temperature(C)','Solar Radiation (MJ/m2)'],lambda df : 0 if (df['Temperature(C)'] < 35) and (df['Humidity(%)'] < 70) and (df['Solar Radiation (MJ/m2)'] < 1.4) else 1,'Weather_bad')

# %%
test['Ideal'] = df_test[['Temperature(C)', 'Wind speed (m/s)']] \
    .apply(lambda df: 1 if (df['Temperature(C)'] < 30 and df['Wind speed (m/s)'] < 2.8) else 0, axis = 1)

# %%
#new_feature_data_series(test,['Temperature(C)','Humidity(%)','Functioning Day'],feels_like,'Feels_like')
new_feature_data_series(test,['Temperature(C)','Dew point temperature(C)','Functioning Day'],humidex,'Humidex')

# %%
new_feature_data_series(test,['Visibility (10m)'],visibility,'Visibility_cat')

# %%
new_feature_data_series(test,['Rainfall(mm)'],rain_fall,'Rain_cat')

# %%
new_feature_data_series(test,['Snowfall (cm)'],snow_fall,'Snow_cat')

# %%
test['Weather_State'] =test[['Temperature(C)', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: "Sunny_hot" if Sunny_Hot(df)\
           else "Clear_hot" if Clear_hot(df)\
           else "PCloudy_hot" if PCloudy_hot(df)\
           else "Cloudy_hot" if Cloudy_hot(df)\
           else "Rain_hot" if Rain_hot(df)\
           else "Night_hot" if Night_hot(df)\
           else "Sunny_Warm" if Sunny_Warm(df)\
           else "Clear_Warm" if Clear_Warm(df)\
           else "PCloudy_Warm" if PCloudy_Warm(df)\
           else "Cloudy_Warm" if Cloudy_Warm(df)\
           else "Rain_Warm" if Rain_Warm(df)\
           else "Night_Warm" if Night_Warm(df)\
           else "Sunny_Cold" if Sunny_Cold(df)\
           else "Clear_Cold" if Clear_Cold(df)\
           else "PCloudy_Cold" if PCloudy_Cold(df)\
           else "Cloudy_Cold" if Cloudy_Cold(df)\
           else "Rain_Cold" if Rain_Cold(df)\
           else "Snow_Cold" if Snow_Cold(df)\
           else "Night_Cold" if Night_Cold(df)\
           else "Sunny_Freezing" if Sunny_Freezing(df)\
           else "Clear_Freezing" if Clear_Freezing(df)\
           else "PCloudy_Freezing" if PCloudy_Freezing(df)\
           else "Cloudy_Freezing" if Cloudy_Freezing(df)\
           else "Rain_Freezing" if Rain_Freezing(df)\
           else "Snow_Freezing" if Snow_Freezing(df)\
           else "Night_Freezing" if Night_Freezing(df)\
           else "Rain&Snow" if Rain_Snow(df)\
           else 0, axis = 1)

# %%
map_data_series(test,'Weather_State',Weather_Description_list,Weather_Description_neumeric)

# %%
test["Date_tmp"] = test['Date'].dt.to_period('M')
test = pd.merge(test, new_feature_df, on="Date_tmp", how="left")

# %%
new_feature_data_series(test,['Visibility (10m)'],visibility_dist,'Visibility_dist')

# %%
new_feature_data_series(test,['Weather_State','Visibility_dist'],lambda df :df['Weather_State']*(df['Visibility_dist']),'Weather_stat&visb_dist')

# %%
new_feature_data_series(test,['Weather_State','Visibility (10m)'],lambda df :df['Weather_State']*np.log(df['Visibility (10m)']),'Weather&visb')

# %%
test['Sky_State'] =test[['Temperature(C)','Visibility_dist', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: 4 if Cond4(df)\
                 else 2 if Cond2(df)\
                 else 3 if Cond3(df)\
                 else 1 if Cond1(df)\
                 else 5, axis = 1)

# %%
test['Temp_State'] =test[['Temperature(C)','Visibility_dist', 'Solar Radiation (MJ/m2)' , 'day_night','Snowfall (cm)','Rainfall(mm)']]  \
    .apply(lambda df: 1 if Warm(df)\
                 else 2 if Cold(df)\
                 else 3 if Hot(df)\
                 else 4 if Freezing(df)\
                 
                 else 5, axis = 1)

# %%
new_feature_data_series(test,['Sky_State','Temp_State'],lambda df :df['Sky_State']*(df['Temp_State']),'GBL_Forecast')

# %%
test.columns

# %%
test['Prev Month y'].fillna((test['Prev Month y'].mean()), inplace=True)

# %%
#test.drop(["Date", "y", "Date_tmp", "Dataset"], axis=1, inplace=True)
Xtest = test[selected_features]
polynomial_Xtest=Xtest
trans = PolynomialFeatures(degree=2)
polynomial_Xtest= trans.fit_transform(polynomial_Xtest)

# %%
print(polynomial_Xtest)

# %%
pred_test = model.predict(polynomial_Xtest)

# %% [markdown]
# ### model Predictions

# %%
from sklearn.metrics import r2_score
df_test_real = pd.read_csv(r"SeoulBikeDataTestFull.csv")
y_pred_real=df_test_real['y']
print('(Real) CatBoost Regression RMSLE:', rmsle(y_pred_real, np.exp(pred_test), False))
print('(Real) CatBoost Regression R2:', r2_score(y_pred_real, np.exp(pred_test)))
#(Real) CatBoost Regression RMSLE:  0.38951815932105094

# %%
from sklearn.metrics import mean_squared_log_error
print(np.sqrt(mean_squared_log_error(y_pred_real,np.exp(pred_test))))
#0.38951815932105094

# %%
#best  0.38951815932105094

# %% [markdown]
# cat,xgb 0.3962361246472995
# cat,gbr 0.3967100264484556
# xgb,gbr 0.39194301021844696  kaggle 0.41849

# %%
df_test.info()

# %%
original_test=pd.read_csv(r"test.csv")
df_test["ID"]=original_test["ID"]
df_test["y"]=np.exp(pred_test)
df_test[["ID", "y"]].to_csv('ultima4.csv', index=False)

# %%
print(df_test["y"])

# %% [markdown]
# ### Save Submission

# %% [markdown]
# #
